# %% [markdown]
# # <center>CSE 4/546: Reinforcement Learning</center>
# ## <center>Prof. Alina Vereshchaka</center>
# ### <center>Assignment 1, Part 3</center>

# %%
# Imports
import gymnasium
from gymnasium import spaces
import math
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### Stock Trading Environment

# %%
# Defining the Stock Trading Environment.
"""DON'T MAKE ANY CHANGES TO THE ENVIRONMENT."""


class StockTradingEnvironment(gymnasium.Env):
    """This class implements the Stock Trading environment."""

    def __init__(self, file_path, train=True, number_of_days_to_consider=10):
        """This method initializes the environment.

        :param file_path: - Path of the CSV file containing the historical stock data.
        :param train: - Boolean indicating whether the goal is to train or test the performance of the agent.
        :param number_of_days_to_consider = Integer representing the number of days the for which the agent
                considers the trend in stock price to make a decision."""

        self.file_path = file_path
        self.stock_data = pd.read_csv(self.file_path)
        self.train = train

        # Splitting the data into train and test datasets.
        self.training_stock_data = self.stock_data.iloc[:int(0.8 * len(self.stock_data))]
        self.testing_stock_data = self.stock_data.iloc[int(0.8 * len(self.stock_data)):].reset_index()

        self.observation_space = spaces.Discrete(4)
        self.action_space = spaces.Discrete(3)

        self.investment_capital = 100000  # This defines the investment capital that the agent starts with.
        self.number_of_shares = 0  # This defines number of shares currently held by the agent.
        self.stock_value = 0  # This defines the value of the stock currently held by the agent.
        self.book_value = 0  # This defines the total value for which the agent bought the shares.
        # This defines the agent's total account value.
        self.total_account_value = self.investment_capital + self.stock_value
        # List to store the total account value over training or evaluation.
        self.total_account_value_list = []
        # This defines the number of days for which the agent considers the data before taking an action.
        self.number_of_days_to_consider = number_of_days_to_consider
        # The maximum timesteps the agent will take before the episode ends.
        if self.train:
            self.max_timesteps = len(self.training_stock_data) - self.number_of_days_to_consider
        else:
            self.max_timesteps = len(self.testing_stock_data) - self.number_of_days_to_consider
        # Initializing the number of steps taken to 0.
        self.timestep = 0
        self.reset()

    def reset(self):
        """This method resets the environment and returns the observation.

        :returns observation: - Integer in the range of 0 to 3 representing the four possible observations that the
                                agent can receive. The observation depends upon whether the price increased on average
                                in the number of days the agent considers, and whether the agent already has the stock
                                or not.

         info: - A dictionary that can be used to provide additional implementation information."""

        self.investment_capital = 100000  # This defines the investment capital that the agent starts with.
        self.number_of_shares = 0  # This defines number of shares currently held by the agent.
        self.stock_value = 0  # This defines the value of the stock currently held by the agent.
        self.book_value = 0  # This defines the total value for which the agent bought the shares.
        # This defines the agent's total account value.
        self.total_account_value = self.investment_capital + self.stock_value
        # List to store the total account value over training or evaluation.
        self.total_account_value_list = []
        # Initializing the number of steps taken to 0.
        self.timestep = 0

        # Getting the observation vector.
        if self.train:
            # If the task is to train the agent the maximum timesteps will be equal to the number of days considered
            # subtracted from the  length of the training stock data.
            self.max_timesteps = len(self.training_stock_data) - self.number_of_days_to_consider

            # Calculating whether the price increased or decreased/remained the same on the majority of days the agent
            # considers.
            price_increase_list = []
            for i in range(self.number_of_days_to_consider):
                if self.training_stock_data['Close'][self.timestep + 1 + i] \
                        - self.training_stock_data['Close'][self.timestep + i] > 0:
                    price_increase_list.append(1)
                else:
                    price_increase_list.append(0)

            if (np.sum(price_increase_list) / self.number_of_days_to_consider) >= 0.5:
                price_increase = True
            else:
                price_increase = False

            stock_held = False

            # Observation vector that will be passed to the agent.
            observation = [price_increase, stock_held]

        else:
            # If the task is to evaluate the trained agent's performance the maximum timesteps will be equal to the
            # number of days considered subtracted from the  length of the testing stock data.
            self.max_timesteps = len(self.testing_stock_data) - self.number_of_days_to_consider

            # Calculating whether the price increased or decreased/remained the same on the majority of days the agent
            # considers.
            price_increase_list = []
            for i in range(self.number_of_days_to_consider):
                if self.testing_stock_data['Close'][self.timestep + 1 + i] \
                        - self.testing_stock_data['Close'][self.timestep + i] > 0:
                    price_increase_list.append(1)
                else:
                    price_increase_list.append(0)

            if (np.sum(price_increase_list) / self.number_of_days_to_consider) >= 0.5:
                price_increase = True
            else:
                price_increase = False

            stock_held = False

            # Observation vector.
            observation = [price_increase, stock_held]

        if np.array_equal(observation, [True, False]):
            observation = 0
        if np.array_equal(observation, [True, True]):
            observation = 1
        if np.array_equal(observation, [False, False]):
            observation = 2
        if np.array_equal(observation, [False, True]):
            observation = 3

        info = None

        return observation, info

    def step(self, action):
        """This method implements what happens when the agent takes the action to Buy/Sell/Hold.

        :param action: - Integer in the range 0 to 2 inclusive.

        :returns observation: - Integer in the range of 0 to 3 representing the four possible observations that the
                                agent can receive. The observation depends upon whether the price increased on average
                                in the number of days the agent considers, and whether the agent already has the stock
                                or not.
                 reward: - Integer/Float value that's used to measure the performance of the agent.
                 terminated: - Boolean describing whether the episode has terminated.
                 truncated: - Boolean describing whether a truncation condition outside the scope of the MDP is satisfied.
                 info: - A dictionary that can be used to provide additional implementation information."""

        # We give the agent a penalty for taking actions such as buying a stock when the agent doesn't have the
        # investment capital and selling a stock when the agent doesn't have any shares.
        penalty = 0

        if self.train:
            if action == 0:  # Buy
                if self.number_of_shares > 0:
                    penalty = -10
                # Determining the number of shares the agent can buy.
                number_of_shares_to_buy = math.floor(self.investment_capital / self.training_stock_data[
                    'Open'][self.timestep + self.number_of_days_to_consider])
                # Adding to the number of shares the agent has.
                self.number_of_shares += number_of_shares_to_buy

                # Computing the stock value, book value, investment capital and reward.
                if number_of_shares_to_buy > 0:
                    self.stock_value +=\
                        self.training_stock_data['Open'][self.timestep + self.number_of_days_to_consider] \
                        * number_of_shares_to_buy
                    self.book_value += \
                        self.training_stock_data['Open'][self.timestep + self.number_of_days_to_consider]\
                        * number_of_shares_to_buy
                    self.investment_capital -= \
                        self.training_stock_data['Open'][self.timestep + self.number_of_days_to_consider] \
                        * number_of_shares_to_buy

                    reward = 1 + penalty

                else:
                    # Computing the stock value and reward.
                    self.stock_value = \
                        self.training_stock_data['Open'][self.timestep + self.number_of_days_to_consider] \
                        * self.number_of_shares
                    reward = -10

            if action == 1:  # Sell
                # Computing the investment capital, sell value and reward.
                self.investment_capital += \
                    self.training_stock_data['Open'][self.timestep + self.number_of_days_to_consider] \
                    * self.number_of_shares
                sell_value = self.training_stock_data['Open'][self.timestep + self.number_of_days_to_consider] \
                             * self.number_of_shares

                if self.book_value > 0:
                    reward = (sell_value - self.book_value) / self.book_value * 100
                else:
                    reward = -10

                self.number_of_shares = 0
                self.stock_value = 0
                self.book_value = 0

            if action == 2:  # Hold
                # Computing the stock value and reward.
                self.stock_value = self.training_stock_data['Open'][self.timestep + self.number_of_days_to_consider] \
                                   * self.number_of_shares

                if self.book_value > 0:
                    reward = (self.stock_value - self.book_value) / self.book_value * 100
                else:
                    reward = -1

        else:
            if action == 0:  # Buy
                if self.number_of_shares > 0:
                    penalty = -10
                # Determining the number of shares the agent can buy.
                number_of_shares_to_buy = math.floor(self.investment_capital / self.testing_stock_data[
                    'Open'][self.timestep + self.number_of_days_to_consider])
                # Adding to the number of shares the agent has.
                self.number_of_shares += number_of_shares_to_buy

                # Computing the stock value, book value, investment capital and reward.
                if number_of_shares_to_buy > 0:
                    self.stock_value += \
                        self.testing_stock_data['Open'][self.timestep + self.number_of_days_to_consider] \
                        * number_of_shares_to_buy
                    self.book_value += \
                        self.testing_stock_data['Open'][self.timestep + self.number_of_days_to_consider] \
                        * number_of_shares_to_buy
                    self.investment_capital -= \
                        self.testing_stock_data['Open'][self.timestep + self.number_of_days_to_consider] \
                        * number_of_shares_to_buy

                    reward = 1 + penalty

                else:
                    # Computing the stock value and reward.
                    self.stock_value = self.training_stock_data['Open'][
                                           self.timestep + self.number_of_days_to_consider] * self.number_of_shares
                    reward = -10

            if action == 1:  # Sell
                # Computing the investment capital, sell value and reward.
                self.investment_capital += \
                    self.testing_stock_data['Open'][self.timestep + self.number_of_days_to_consider] \
                    * self.number_of_shares
                sell_value = self.training_stock_data['Open'][self.timestep + self.number_of_days_to_consider] \
                             * self.number_of_shares

                if self.book_value > 0:
                    reward = (sell_value - self.book_value) / self.book_value * 100
                else:
                    reward = -10

                self.number_of_shares = 0
                self.stock_value = 0
                self.book_value = 0

            if action == 2:  # Hold
                # Computing the stock value and reward.
                self.stock_value = self.testing_stock_data['Open'][self.timestep + self.number_of_days_to_consider] \
                                   * self.number_of_shares

                if self.book_value > 0:
                    reward = (self.stock_value - self.book_value) / self.book_value * 100
                else:
                    reward = -1

        # Determining if the agent currently has shares of the stock or not.
        if self.number_of_shares > 0:
            stock_held = True
        else:
            stock_held = False

        # Getting the observation vector.
        if self.train:
            # If the task is to train the agent the maximum timesteps will be equal to the number of days considered
            # subtracted from the  length of the training stock data.
            self.max_timesteps = len(self.training_stock_data) - self.number_of_days_to_consider

            # Calculating whether the price increased or decreased/remained the same on the majority of days the agent
            # considers.
            price_increase_list = []
            for i in range(self.number_of_days_to_consider):
                if self.training_stock_data['Close'][self.timestep + 1 + i] \
                        - self.training_stock_data['Close'][self.timestep + i] > 0:
                    price_increase_list.append(1)
                else:
                    price_increase_list.append(0)

            if (np.sum(price_increase_list) / self.number_of_days_to_consider) >= 0.5:
                price_increase = True
            else:
                price_increase = False

            # Observation vector.
            observation = [price_increase, stock_held]

        else:
            # If the task is to evaluate the trained agent's performance the maximum timesteps will be equal to the
            # number of days considered subtracted from the  length of the testing stock data.
            self.max_timesteps = len(self.testing_stock_data) - self.number_of_days_to_consider

            # Calculating whether the price increased or decreased/remained the same on the majority of days the agent
            # considers.
            price_increase_list = []
            for i in range(self.number_of_days_to_consider):
                if self.testing_stock_data['Close'][self.timestep + 1 + i] \
                        - self.testing_stock_data['Close'][self.timestep + i] > 0:
                    price_increase_list.append(1)
                else:
                    price_increase_list.append(0)

            if (np.sum(price_increase_list) / self.number_of_days_to_consider) >= 0.5:
                price_increase = True
            else:
                price_increase = False

            # Observation vector.
            observation = [price_increase, stock_held]

        self.timestep += 1  # Increasing the number of steps taken by the agent by 1.

        if np.array_equal(observation, [True, False]):
            observation = 0
        if np.array_equal(observation, [True, True]):
            observation = 1
        if np.array_equal(observation, [False, False]):
            observation = 2
        if np.array_equal(observation, [False, True]):
            observation = 3

        # Computing the total account value.
        self.total_account_value = self.investment_capital + self.stock_value
        # Appending the total account value of the list to plot the graph.
        self.total_account_value_list.append(self.total_account_value)

        # The episode terminates when the maximum timesteps have been reached.
        terminated = True if (self.timestep >= self.max_timesteps) \
            else False
        truncated = False
        info = {}

        return observation, reward, terminated, truncated, info

    def render(self, mode='human'):
        """This method renders the agent's total account value over time.

        :param mode: 'human' renders to the current display or terminal and returns nothing."""

        plt.figure(figsize=(15, 10))
        plt.plot(self.total_account_value_list, color='lightseagreen', linewidth=7)
        plt.xlabel('Days', fontsize=32)
        plt.ylabel('Total Account Value', fontsize=32)
        plt.title('Total Account Value over Time', fontsize=38)
        plt.grid()
        plt.show()

# %%
# NOTE: You can adjust the parameter 'number_of_days_to_consider'. To train the agent, set 'train=True', and to evaluate the agent, set 'train=False'.

stock_trading_environment = StockTradingEnvironment(file_path='./NVDA.csv', train=True, number_of_days_to_consider=10)

# %% [markdown]
# ### TO DO: Implement the Q-learning algorithm

# %%
import numpy as np
import math
import pandas as pd
import pickle

def q_learning(num_episodes=1000, alpha=0.1, gamma=0.99, epsilon=1.0, epsilon_decay=0.995, epsilon_min=0.01, training=False):

    env = StockTradingEnvironment(file_path='./NVDA.csv', train=training, number_of_days_to_consider=10)

    num_states = env.observation_space.n
    num_actions = env.action_space.n
    rewards = []
    epsilons = []

    if training:
        q_table = np.zeros((num_states, num_actions))
    else:
        f = open("stock_trading.pkl","rb")
        q_table = pickle.load(f)
        f.close()

    for episode in range(num_episodes):
        state, info = env.reset()
        done = False
        total_reward = 0

        while not done:
            if np.random.rand() < epsilon:
                action = np.random.randint(num_actions)
            else:
                action = np.argmax(q_table[state])

            next_state, reward, terminated, truncated, info = env.step(action)
            done = terminated or truncated

            q_table[state, action] = q_table[state, action] + alpha * (
                reward + gamma * np.max(q_table[next_state]) - q_table[state, action]
            )

            state = next_state
            total_reward += reward

        rewards.append(total_reward)
        epsilon = max(epsilon * epsilon_decay, epsilon_min)
        epsilons.append(epsilon)
        print(f"Episode {episode+1}: Total Reward = {total_reward}")
    if training:
        f = open("stock_trading.pkl","wb")
        pickle.dump(q_table, f)
        f.close()
    
        print("###############################################")
        print("            Trained Q-Table:")
        print("###############################################")
        print(q_table)
        
        plt.xlabel('Episodes')
        plt.ylabel('Total reward per episode')
        plt.plot(rewards)
        plt.title("Total reward per episode VS Episodes")
        plt.show()
        plt.xlabel('Episodes')
        plt.ylabel('Epsilon Value')
        plt.plot(epsilons)
        plt.title("Epsilon Value VS Episodes")
        plt.show()
    else:
        env.render()

# %% [markdown]
# ## Training the Q-Learning Algorithm for 1000 episodes

# %%
q_learning(num_episodes=1000, alpha=0.1, gamma=0.99, epsilon=1.0, epsilon_decay=0.995, epsilon_min=0.01, training=True)
# Out:
# Episode 1: Total Reward = -1285.8877603471426
# Episode 2: Total Reward = -1010.8251254410965
# Episode 3: Total Reward = -1044.9858639662853
# Episode 4: Total Reward = -1166.8824229739232
# Episode 5: Total Reward = -1158.4216637459722
# Episode 6: Total Reward = -1229.410947450859
# Episode 7: Total Reward = -1177.181973521054
# Episode 8: Total Reward = -1230.7157929005512
# Episode 9: Total Reward = -1192.2654093356648
# Episode 10: Total Reward = -1166.1416455283095
# Episode 11: Total Reward = -1110.9393499538273
# Episode 12: Total Reward = -873.3769262454739
# Episode 13: Total Reward = -1012.8233709111323
# Episode 14: Total Reward = -1191.9817956776049
# Episode 15: Total Reward = -1013.9757484123901
# Episode 16: Total Reward = -1137.5443326010834
# Episode 17: Total Reward = -1155.8558306581865
# Episode 18: Total Reward = -1028.198149666594
# Episode 19: Total Reward = -1275.3340750024074
# Episode 20: Total Reward = -1001.9192644381238
# Episode 21: Total Reward = -1082.6649533449033
# Episode 22: Total Reward = -857.6623531427393
# Episode 23: Total Reward = -1108.6682485274096
# Episode 24: Total Reward = -770.3693910637904
# Episode 25: Total Reward = -879.5734156154255
# Episode 26: Total Reward = -702.5407155461319
# Episode 27: Total Reward = -1109.1368589690317
# Episode 28: Total Reward = -881.6340795737224
# Episode 29: Total Reward = -933.3239634164682
# Episode 30: Total Reward = -1000.8569722168423
# Episode 31: Total Reward = -961.2808918242104
# Episode 32: Total Reward = -667.4301956803996
# Episode 33: Total Reward = -1131.4806486358032
# Episode 34: Total Reward = -973.3922208132076
# Episode 35: Total Reward = -883.2213332262847
# Episode 36: Total Reward = -526.5011338591975
# Episode 37: Total Reward = -820.902098689829
# Episode 38: Total Reward = -822.9249900451553
# Episode 39: Total Reward = -704.6966163690408
# Episode 40: Total Reward = -589.7269942526284
# Episode 41: Total Reward = -513.509305927106
# Episode 42: Total Reward = -944.6493332716857
# Episode 43: Total Reward = -703.6658430088607
# Episode 44: Total Reward = -971.659919616197
# Episode 45: Total Reward = -669.6901540934596
# Episode 46: Total Reward = -676.3984391849335
# Episode 47: Total Reward = -594.7225264519527
# Episode 48: Total Reward = -828.9244546649926
# Episode 49: Total Reward = -1025.438033006764
# Episode 50: Total Reward = -446.9097997961808
# Episode 51: Total Reward = -1012.0613247462369
# Episode 52: Total Reward = -462.05046912350775
# Episode 53: Total Reward = -638.2510265643986
# Episode 54: Total Reward = -692.0851060651986
# Episode 55: Total Reward = -843.7674335250628
# Episode 56: Total Reward = -970.7084793011817
# Episode 57: Total Reward = -750.6882297388667
# Episode 58: Total Reward = -634.7196865846753
# Episode 59: Total Reward = -663.2552241143411
# Episode 60: Total Reward = -642.4130832183522
# Episode 61: Total Reward = -610.47512042518
# Episode 62: Total Reward = -654.4376174268542
# Episode 63: Total Reward = -849.5957520202954
# Episode 64: Total Reward = -468.9693212297889
# Episode 65: Total Reward = -666.9056383298016
# Episode 66: Total Reward = -456.5461272442672
# Episode 67: Total Reward = -582.6149216713123
# Episode 68: Total Reward = -431.93728202365577
# Episode 69: Total Reward = -659.2689723037488
# Episode 70: Total Reward = -572.0161565125577
# Episode 71: Total Reward = -458.9719750564684
# Episode 72: Total Reward = -480.05112140365316
# Episode 73: Total Reward = -502.6612823448765
# Episode 74: Total Reward = -618.4335704815499
# Episode 75: Total Reward = -451.46205914863043
# Episode 76: Total Reward = -488.01365146305716
# Episode 77: Total Reward = -393.7411740071692
# Episode 78: Total Reward = -480.2366575422374
# Episode 79: Total Reward = -563.7002359250527
# Episode 80: Total Reward = -626.7560724851647
# Episode 81: Total Reward = -310.7550412137505
# Episode 82: Total Reward = -532.3364365281383
# Episode 83: Total Reward = -643.9677121883174
# Episode 84: Total Reward = -242.77113749931837
# Episode 85: Total Reward = -237.73473571192508
# Episode 86: Total Reward = -111.13500378917844
# Episode 87: Total Reward = -290.8078035321566
# Episode 88: Total Reward = -943.4986476419633
# Episode 89: Total Reward = -652.4395707957001
# Episode 90: Total Reward = -277.68407241264634
# Episode 91: Total Reward = -49.254464816853606
# Episode 92: Total Reward = -586.8490924867159
# Episode 93: Total Reward = -686.1708503072635
# Episode 94: Total Reward = -321.8130832720777
# Episode 95: Total Reward = -367.1700551636064
# Episode 96: Total Reward = -269.7002120103946
# Episode 97: Total Reward = -601.0301352210588
# Episode 98: Total Reward = -582.3436219065002
# Episode 99: Total Reward = -31.558102677515905
# Episode 100: Total Reward = -513.2998520098982
# Episode 101: Total Reward = -264.1543784765419
# Episode 102: Total Reward = -401.2554053386028
# Episode 103: Total Reward = -435.4757556495892
# Episode 104: Total Reward = -94.1330360274172
# Episode 105: Total Reward = -305.95721782064203
# Episode 106: Total Reward = -123.72231658654802
# Episode 107: Total Reward = -264.75875781971115
# Episode 108: Total Reward = -9.230728665613153
# Episode 109: Total Reward = -473.3866904139182
# Episode 110: Total Reward = -330.4859537458597
# Episode 111: Total Reward = -156.59703177940182
# Episode 112: Total Reward = -284.6169159110956
# Episode 113: Total Reward = -394.02575661039197
# Episode 114: Total Reward = 726.9060103777717
# Episode 115: Total Reward = -495.98118774816584
# Episode 116: Total Reward = -304.9951733720835
# Episode 117: Total Reward = 221.56591011802715
# Episode 118: Total Reward = -359.4187288407673
# Episode 119: Total Reward = 467.05821086872356
# Episode 120: Total Reward = 277.35521947625773
# Episode 121: Total Reward = -51.248842278843924
# Episode 122: Total Reward = -655.846775458574
# Episode 123: Total Reward = -351.50413169106577
# Episode 124: Total Reward = -124.50716293490753
# Episode 125: Total Reward = -40.03071988692699
# Episode 126: Total Reward = -210.65964779212578
# Episode 127: Total Reward = 114.32606179655818
# Episode 128: Total Reward = -229.77613366217352
# Episode 129: Total Reward = 130.60651545632533
# Episode 130: Total Reward = -318.8969922092507
# Episode 131: Total Reward = 10.253044577954448
# Episode 132: Total Reward = -355.13561772906246
# Episode 133: Total Reward = 79.918345623523
# Episode 134: Total Reward = -20.073037430167933
# Episode 135: Total Reward = -220.40540651839464
# Episode 136: Total Reward = -132.15852804182336
# Episode 137: Total Reward = -231.19864862271254
# Episode 138: Total Reward = -129.9543660569202
# Episode 139: Total Reward = -205.94750114116007
# Episode 140: Total Reward = 1271.153529065399
# Episode 141: Total Reward = 53.94862884651551
# Episode 142: Total Reward = -364.8701390114608
# Episode 143: Total Reward = 70.22544787225061
# Episode 144: Total Reward = 38.51555467413509
# Episode 145: Total Reward = -219.33738615531698
# Episode 146: Total Reward = -66.04239379108245
# Episode 147: Total Reward = -137.39954612646937
# Episode 148: Total Reward = -131.3829998930311
# Episode 149: Total Reward = -123.90577551770019
# Episode 150: Total Reward = 516.9109227273292
# Episode 151: Total Reward = 319.0440810005878
# Episode 152: Total Reward = 325.80507546817216
# Episode 153: Total Reward = -235.66913493190003
# Episode 154: Total Reward = 48.22411458511771
# Episode 155: Total Reward = -238.4506406283565
# Episode 156: Total Reward = -356.5573251966609
# Episode 157: Total Reward = 327.95096473528287
# Episode 158: Total Reward = 230.91272803410314
# Episode 159: Total Reward = 221.42585936226808
# Episode 160: Total Reward = 375.09404701867817
# Episode 161: Total Reward = -112.23167220246542
# Episode 162: Total Reward = -161.5045287167872
# Episode 163: Total Reward = 568.1937343558596
# Episode 164: Total Reward = -141.49824612089478
# Episode 165: Total Reward = 172.46901931480838
# Episode 166: Total Reward = 760.1041487187838
# Episode 167: Total Reward = 417.8117376977681
# Episode 168: Total Reward = 452.3616818574657
# Episode 169: Total Reward = 241.96213049012508
# Episode 170: Total Reward = 116.36206598563648
# Episode 171: Total Reward = 447.76621943606693
# Episode 172: Total Reward = 205.51373836083823
# Episode 173: Total Reward = -5.115864592335603
# Episode 174: Total Reward = 537.5762564529755
# Episode 175: Total Reward = -75.80867760296373
# Episode 176: Total Reward = -156.69997416819095
# Episode 177: Total Reward = 162.4226486209578
# Episode 178: Total Reward = 676.4301118621705
# Episode 179: Total Reward = 1002.4329228738324
# Episode 180: Total Reward = -171.77572686064667
# Episode 181: Total Reward = 450.8773800100182
# Episode 182: Total Reward = 357.204940546735
# Episode 183: Total Reward = -73.56007670470775
# Episode 184: Total Reward = 57.98569875707352
# Episode 185: Total Reward = 257.76442322042146
# Episode 186: Total Reward = 526.1491650513643
# Episode 187: Total Reward = 175.58818165766547
# Episode 188: Total Reward = 154.37473116901788
# Episode 189: Total Reward = 105.41151746583284
# Episode 190: Total Reward = 1340.6181452393544
# Episode 191: Total Reward = 516.7907350397429
# Episode 192: Total Reward = 986.2465616240219
# Episode 193: Total Reward = 569.0697445541845
# Episode 194: Total Reward = 370.04562699518465
# Episode 195: Total Reward = 363.98547130937675
# Episode 196: Total Reward = 59.65572293284821
# Episode 197: Total Reward = 179.22234818760933
# Episode 198: Total Reward = 1246.4552783283777
# Episode 199: Total Reward = 481.1073478831161
# Episode 200: Total Reward = 33.61094517362142
# Episode 201: Total Reward = 844.9220010208303
# Episode 202: Total Reward = -273.4333205316532
# Episode 203: Total Reward = 398.26545119609654
# Episode 204: Total Reward = 193.48185665014108
# Episode 205: Total Reward = 483.72581682642146
# Episode 206: Total Reward = 167.14768498422256
# Episode 207: Total Reward = 765.491404337233
# Episode 208: Total Reward = 728.5762795285902
# Episode 209: Total Reward = 215.45557158408818
# Episode 210: Total Reward = 450.7938210117219
# Episode 211: Total Reward = 415.9473240858992
# Episode 212: Total Reward = 302.06917552121786
# Episode 213: Total Reward = 448.23527691104397
# Episode 214: Total Reward = 91.29742581379054
# Episode 215: Total Reward = 1370.906825534504
# Episode 216: Total Reward = 661.5063725084428
# Episode 217: Total Reward = -182.5097597221675
# Episode 218: Total Reward = 616.9837696852268
# Episode 219: Total Reward = 750.1200239825351
# Episode 220: Total Reward = 423.96796024158533
# Episode 221: Total Reward = 221.2066644440542
# Episode 222: Total Reward = 869.941098209414
# Episode 223: Total Reward = 586.9241940234971
# Episode 224: Total Reward = 514.953236978719
# Episode 225: Total Reward = 189.54190354807437
# Episode 226: Total Reward = 1280.4429457125339
# Episode 227: Total Reward = 1040.2606455190294
# Episode 228: Total Reward = 653.4875510861539
# Episode 229: Total Reward = 771.3174742477727
# Episode 230: Total Reward = 1326.1485503545236
# Episode 231: Total Reward = -162.15047719209085
# Episode 232: Total Reward = 1888.731458054214
# Episode 233: Total Reward = 31.042335679114423
# Episode 234: Total Reward = -45.75293753384996
# Episode 235: Total Reward = -62.08938516221027
# Episode 236: Total Reward = 1121.9973942418642
# Episode 237: Total Reward = 367.321571590438
# Episode 238: Total Reward = 720.8669061006375
# Episode 239: Total Reward = 1036.472579818536
# Episode 240: Total Reward = 1663.325984528741
# Episode 241: Total Reward = -342.15861557695746
# Episode 242: Total Reward = 400.658795984971
# Episode 243: Total Reward = 559.9771902282588
# Episode 244: Total Reward = 106.80803609521114
# Episode 245: Total Reward = 307.4597212174802
# Episode 246: Total Reward = 1161.4806341256767
# Episode 247: Total Reward = 1136.4351335012598
# Episode 248: Total Reward = 794.7767208163133
# Episode 249: Total Reward = 726.3623384348124
# Episode 250: Total Reward = 807.5321910526421
# Episode 251: Total Reward = 1035.0072686057997
# Episode 252: Total Reward = 692.5894603997531
# Episode 253: Total Reward = 328.249135812049
# Episode 254: Total Reward = 449.42491887894283
# Episode 255: Total Reward = 1370.4740794945947
# Episode 256: Total Reward = 1701.8347006727004
# Episode 257: Total Reward = 1692.0277911690955
# Episode 258: Total Reward = 1015.2891532795044
# Episode 259: Total Reward = 1519.5066920068828
# Episode 260: Total Reward = 1544.2424182331483
# Episode 261: Total Reward = 218.92963259655497
# Episode 262: Total Reward = 301.13611699866345
# Episode 263: Total Reward = 398.15070026203364
# Episode 264: Total Reward = 327.8993260312221
# Episode 265: Total Reward = 1253.860367650636
# Episode 266: Total Reward = 934.1525423841612
# Episode 267: Total Reward = 1608.6807684371006
# Episode 268: Total Reward = 1706.216832467562
# Episode 269: Total Reward = 1519.475409846779
# Episode 270: Total Reward = 532.0177467151892
# Episode 271: Total Reward = 1314.3458366741015
# Episode 272: Total Reward = 224.71910095887236
# Episode 273: Total Reward = 839.4563367060256
# Episode 274: Total Reward = 591.8547912269588
# Episode 275: Total Reward = 1374.8264941421799
# Episode 276: Total Reward = 1241.692835924408
# Episode 277: Total Reward = -100.02968688378986
# Episode 278: Total Reward = 716.4062288944709
# Episode 279: Total Reward = 1342.8826436868362
# Episode 280: Total Reward = 2278.2903441267554
# Episode 281: Total Reward = 443.0375932992163
# Episode 282: Total Reward = 332.3252298009981
# Episode 283: Total Reward = 544.1717625704752
# Episode 284: Total Reward = 1012.438997674243
# Episode 285: Total Reward = 755.6657578171547
# Episode 286: Total Reward = 1956.9650558833198
# Episode 287: Total Reward = 1052.9529470880975
# Episode 288: Total Reward = 1675.8895002581044
# Episode 289: Total Reward = 306.1617177686486
# Episode 290: Total Reward = 3172.622191952359
# Episode 291: Total Reward = 1857.2282734835217
# Episode 292: Total Reward = 2135.612643192726
# Episode 293: Total Reward = -531.9610659657941
# Episode 294: Total Reward = 1035.6047577852771
# Episode 295: Total Reward = 542.8438440192399
# Episode 296: Total Reward = 2239.5079340395814
# Episode 297: Total Reward = 1046.4171941425122
# Episode 298: Total Reward = 437.3753093534746
# Episode 299: Total Reward = 596.3655005834183
# Episode 300: Total Reward = 838.3781037664038
# Episode 301: Total Reward = 334.53904721017045
# Episode 302: Total Reward = -202.3745285183269
# Episode 303: Total Reward = 1354.7879126072771
# Episode 304: Total Reward = 1662.9806260403677
# Episode 305: Total Reward = 1345.46334463162
# Episode 306: Total Reward = 1052.9512837139664
# Episode 307: Total Reward = 1629.1341346674456
# Episode 308: Total Reward = 783.068868547451
# Episode 309: Total Reward = 908.7630957664792
# Episode 310: Total Reward = 2954.8043019823776
# Episode 311: Total Reward = 464.19748011312527
# Episode 312: Total Reward = 204.18802768846655
# Episode 313: Total Reward = 1721.7802542011543
# Episode 314: Total Reward = 1905.9794129342083
# Episode 315: Total Reward = 1143.8142065410575
# Episode 316: Total Reward = 233.1738795856784
# Episode 317: Total Reward = 2874.1977584935667
# Episode 318: Total Reward = 818.6303352374825
# Episode 319: Total Reward = 754.4203044120561
# Episode 320: Total Reward = 1901.5620569530636
# Episode 321: Total Reward = 1572.6829053940016
# Episode 322: Total Reward = 1946.2105376660797
# Episode 323: Total Reward = 1575.0605669750762
# Episode 324: Total Reward = 172.610427262467
# Episode 325: Total Reward = 989.193076568737
# Episode 326: Total Reward = 1872.377716579042
# Episode 327: Total Reward = 2303.914353636926
# Episode 328: Total Reward = 1163.0607597729365
# Episode 329: Total Reward = 2642.3918514922057
# Episode 330: Total Reward = 2498.802199293639
# Episode 331: Total Reward = 86.36997521756498
# Episode 332: Total Reward = 908.7327373326852
# Episode 333: Total Reward = 747.6985744744641
# Episode 334: Total Reward = 1368.3339972933234
# Episode 335: Total Reward = 2835.7021141393766
# Episode 336: Total Reward = 4750.861064350381
# Episode 337: Total Reward = 1748.2657581183482
# Episode 338: Total Reward = 1492.8011184335494
# Episode 339: Total Reward = 525.8216277866991
# Episode 340: Total Reward = 1294.12043755547
# Episode 341: Total Reward = 1719.642793278823
# Episode 342: Total Reward = 577.1151008679642
# Episode 343: Total Reward = 991.8789048770808
# Episode 344: Total Reward = 883.8949630189586
# Episode 345: Total Reward = 849.317104609467
# Episode 346: Total Reward = 1173.8064694464895
# Episode 347: Total Reward = 3325.2469147417073
# Episode 348: Total Reward = 4558.81144127619
# Episode 349: Total Reward = 4155.701862730797
# Episode 350: Total Reward = 2225.693763643176
# Episode 351: Total Reward = 784.3183770757284
# Episode 352: Total Reward = 3689.7674178746724
# Episode 353: Total Reward = -269.66594027966835
# Episode 354: Total Reward = 1557.7706598801942
# Episode 355: Total Reward = 1291.1406757028215
# Episode 356: Total Reward = 1453.7241635960645
# Episode 357: Total Reward = 1173.287898297634
# Episode 358: Total Reward = 2559.910297966225
# Episode 359: Total Reward = 877.8665556646984
# Episode 360: Total Reward = 1240.634114063245
# Episode 361: Total Reward = 3571.9758428906503
# Episode 362: Total Reward = 2385.1395176808287
# Episode 363: Total Reward = 3469.269757532374
# Episode 364: Total Reward = -387.20566260608024
# Episode 365: Total Reward = 1455.5138015329194
# Episode 366: Total Reward = 882.89571632963
# Episode 367: Total Reward = 66.16941297870449
# Episode 368: Total Reward = 2796.293620978056
# Episode 369: Total Reward = 3590.119960083983
# Episode 370: Total Reward = 2068.30479349558
# Episode 371: Total Reward = 2448.1023539932253
# Episode 372: Total Reward = 4275.523782136115
# Episode 373: Total Reward = 3423.836254530244
# Episode 374: Total Reward = -285.52443610873127
# Episode 375: Total Reward = 824.3781878720189
# Episode 376: Total Reward = 1616.8935236698687
# Episode 377: Total Reward = 1473.2860809389383
# Episode 378: Total Reward = 7276.6257072503195
# Episode 379: Total Reward = 353.2706137524008
# Episode 380: Total Reward = 2061.513941927829
# Episode 381: Total Reward = 1848.299766521248
# Episode 382: Total Reward = 1195.7515230697718
# Episode 383: Total Reward = 3238.1172714237027
# Episode 384: Total Reward = 1175.5534647030074
# Episode 385: Total Reward = 1079.3928491933953
# Episode 386: Total Reward = 3483.6207502855277
# Episode 387: Total Reward = 2225.725141661572
# Episode 388: Total Reward = 3410.6318803549857
# Episode 389: Total Reward = 1987.3352515034703
# Episode 390: Total Reward = 2657.022071014433
# Episode 391: Total Reward = 2085.04934790437
# Episode 392: Total Reward = 3997.7908222443834
# Episode 393: Total Reward = 4769.032333399226
# Episode 394: Total Reward = 3612.866758156315
# Episode 395: Total Reward = 3805.5108864834137
# Episode 396: Total Reward = 885.4450381817227
# Episode 397: Total Reward = 1166.8447652967561
# Episode 398: Total Reward = 287.2655646503655
# Episode 399: Total Reward = 370.02095975887823
# Episode 400: Total Reward = 519.2520649094669
# Episode 401: Total Reward = 1131.837935475015
# Episode 402: Total Reward = 496.0801065331297
# Episode 403: Total Reward = 711.38274236033
# Episode 404: Total Reward = 667.4469454081575
# Episode 405: Total Reward = 832.4480026913486
# Episode 406: Total Reward = 1732.531362992664
# Episode 407: Total Reward = 5322.849371869016
# Episode 408: Total Reward = 5038.433155916916
# Episode 409: Total Reward = 1921.4263994869266
# Episode 410: Total Reward = 4761.881818060858
# Episode 411: Total Reward = 2984.1223588961066
# Episode 412: Total Reward = 6783.078004985614
# Episode 413: Total Reward = -515.2517910192369
# Episode 414: Total Reward = 2047.071708994356
# Episode 415: Total Reward = 6917.375650464088
# Episode 416: Total Reward = 1844.8174361591543
# Episode 417: Total Reward = 56.80935917863592
# Episode 418: Total Reward = 4546.648742999649
# Episode 419: Total Reward = 2831.660612099107
# Episode 420: Total Reward = 909.3786832580698
# Episode 421: Total Reward = 3910.8223279466742
# Episode 422: Total Reward = -129.3028185001487
# Episode 423: Total Reward = 965.45790356106
# Episode 424: Total Reward = 3791.5659564593398
# Episode 425: Total Reward = 3966.168405131576
# Episode 426: Total Reward = 3323.010507560647
# Episode 427: Total Reward = 8778.973875754782
# Episode 428: Total Reward = 3441.663540994583
# Episode 429: Total Reward = 1017.1221180095055
# Episode 430: Total Reward = -423.8342091242525
# Episode 431: Total Reward = 5612.646541646227
# Episode 432: Total Reward = -69.10963549067343
# Episode 433: Total Reward = 41.22900291870542
# Episode 434: Total Reward = -52.332030014762
# Episode 435: Total Reward = 1303.1507204290365
# Episode 436: Total Reward = 3571.0701707641656
# Episode 437: Total Reward = 1160.8188140689288
# Episode 438: Total Reward = 2726.0177879086086
# Episode 439: Total Reward = 1593.873541618217
# Episode 440: Total Reward = 1136.5399074071017
# Episode 441: Total Reward = 4033.4269836755175
# Episode 442: Total Reward = 3115.7225514993083
# Episode 443: Total Reward = 5697.525291438091
# Episode 444: Total Reward = 3962.4369249751353
# Episode 445: Total Reward = 7366.4448781560495
# Episode 446: Total Reward = 867.776257294531
# Episode 447: Total Reward = -525.080996667706
# Episode 448: Total Reward = -381.6874408533274
# Episode 449: Total Reward = 1123.5229993863466
# Episode 450: Total Reward = 2428.8114924464826
# Episode 451: Total Reward = 2988.090876089327
# Episode 452: Total Reward = 1807.3065128095725
# Episode 453: Total Reward = 33.55140809978628
# Episode 454: Total Reward = 1704.435656610561
# Episode 455: Total Reward = 306.14390830769554
# Episode 456: Total Reward = 8979.880784141043
# Episode 457: Total Reward = 1517.8991278113242
# Episode 458: Total Reward = -327.5295785115882
# Episode 459: Total Reward = 2420.854977716355
# Episode 460: Total Reward = 244.14827649480702
# Episode 461: Total Reward = 7052.609882146853
# Episode 462: Total Reward = 4192.056567615433
# Episode 463: Total Reward = 4595.323170467867
# Episode 464: Total Reward = 8008.155519509377
# Episode 465: Total Reward = 6827.5050129203055
# Episode 466: Total Reward = 5724.025751761711
# Episode 467: Total Reward = 2822.4068009364933
# Episode 468: Total Reward = 650.0309604111014
# Episode 469: Total Reward = 27.99748591698063
# Episode 470: Total Reward = 909.5489965512849
# Episode 471: Total Reward = 848.1852887107624
# Episode 472: Total Reward = -227.2988887975537
# Episode 473: Total Reward = 1262.4999353690564
# Episode 474: Total Reward = 3370.926946415886
# Episode 475: Total Reward = 2870.4153199721795
# Episode 476: Total Reward = 2328.7306780561908
# Episode 477: Total Reward = 263.2247986284417
# Episode 478: Total Reward = 5250.561848130046
# Episode 479: Total Reward = 1709.5862651663087
# Episode 480: Total Reward = 4857.275743565614
# Episode 481: Total Reward = 2841.6641113181154
# Episode 482: Total Reward = 373.6120655630583
# Episode 483: Total Reward = 1260.4973480489732
# Episode 484: Total Reward = 4643.470576307084
# Episode 485: Total Reward = 3905.634692217956
# Episode 486: Total Reward = 1378.1133003690693
# Episode 487: Total Reward = 1717.462580294801
# Episode 488: Total Reward = 5532.860780290112
# Episode 489: Total Reward = 695.5216527518853
# Episode 490: Total Reward = 2719.9902322582116
# Episode 491: Total Reward = 3869.2473222737362
# Episode 492: Total Reward = -443.836699581513
# Episode 493: Total Reward = 786.399755194201
# Episode 494: Total Reward = 2961.335936330683
# Episode 495: Total Reward = 239.19561343008547
# Episode 496: Total Reward = 9053.2965928244
# Episode 497: Total Reward = 652.1772384660674
# Episode 498: Total Reward = 6286.954086716536
# Episode 499: Total Reward = 8009.532507381175
# Episode 500: Total Reward = 10638.349530840731
# Episode 501: Total Reward = 3892.4700127338456
# Episode 502: Total Reward = 1370.920634478704
# Episode 503: Total Reward = 17089.26146250982
# Episode 504: Total Reward = 10626.27514212705
# Episode 505: Total Reward = 4929.554449519802
# Episode 506: Total Reward = 4384.575413397472
# Episode 507: Total Reward = 352.2349016710462
# Episode 508: Total Reward = -753.1560120653089
# Episode 509: Total Reward = -9.19795846462218
# Episode 510: Total Reward = -211.86006941947437
# Episode 511: Total Reward = 338.4149689357342
# Episode 512: Total Reward = 3583.427416372906
# Episode 513: Total Reward = 9177.938138556028
# Episode 514: Total Reward = 10596.912038834114
# Episode 515: Total Reward = 2877.1591483141283
# Episode 516: Total Reward = 1138.2163761510144
# Episode 517: Total Reward = 264.5451661860401
# Episode 518: Total Reward = -446.95099552452973
# Episode 519: Total Reward = 0.613942463285797
# Episode 520: Total Reward = 3727.152796712443
# Episode 521: Total Reward = 5295.621194808288
# Episode 522: Total Reward = -1014.2489092334331
# Episode 523: Total Reward = 5346.729035568138
# Episode 524: Total Reward = 3373.2067879889914
# Episode 525: Total Reward = 1093.2175824044841
# Episode 526: Total Reward = 6795.624127196308
# Episode 527: Total Reward = 21942.05099323813
# Episode 528: Total Reward = 6227.354981182761
# Episode 529: Total Reward = 3495.5052028254963
# Episode 530: Total Reward = 2561.8967944522296
# Episode 531: Total Reward = -723.8999253870908
# Episode 532: Total Reward = -782.1238312430328
# Episode 533: Total Reward = 125.96411284328667
# Episode 534: Total Reward = 1040.6202187792157
# Episode 535: Total Reward = 10289.282896051853
# Episode 536: Total Reward = 4160.289824854123
# Episode 537: Total Reward = 3843.9633270155377
# Episode 538: Total Reward = 7452.380105627214
# Episode 539: Total Reward = -1650.482146471959
# Episode 540: Total Reward = -21.16127159088779
# Episode 541: Total Reward = -558.6802255962848
# Episode 542: Total Reward = -434.5412058388415
# Episode 543: Total Reward = 8024.886351910953
# Episode 544: Total Reward = 16470.365645308568
# Episode 545: Total Reward = 15811.53418041278
# Episode 546: Total Reward = 3691.428025633962
# Episode 547: Total Reward = 9357.887709619563
# Episode 548: Total Reward = 11213.07198936501
# Episode 549: Total Reward = 6395.634277666105
# Episode 550: Total Reward = 14314.862747485598
# Episode 551: Total Reward = 6429.293122219066
# Episode 552: Total Reward = 6340.107304508147
# Episode 553: Total Reward = -100.05291731286334
# Episode 554: Total Reward = -449.80062627009073
# Episode 555: Total Reward = 973.6023298845587
# Episode 556: Total Reward = -49.694201106385336
# Episode 557: Total Reward = 378.8550831974057
# Episode 558: Total Reward = -344.9042456380846
# Episode 559: Total Reward = -270.3917281199635
# Episode 560: Total Reward = -558.0581414481017
# Episode 561: Total Reward = 12289.810139887393
# Episode 562: Total Reward = 6431.464268207546
# Episode 563: Total Reward = 7515.597989437833
# Episode 564: Total Reward = 2849.5965557000804
# Episode 565: Total Reward = -14.030914218960746
# Episode 566: Total Reward = -477.2438733678262
# Episode 567: Total Reward = -884.3502340313623
# Episode 568: Total Reward = 741.3523436971476
# Episode 569: Total Reward = 1588.3184188638409
# Episode 570: Total Reward = 5450.3282384805625
# Episode 571: Total Reward = -1341.0930082641062
# Episode 572: Total Reward = 4230.628710456911
# Episode 573: Total Reward = 1692.613142161655
# Episode 574: Total Reward = -740.5159046236055
# Episode 575: Total Reward = 8696.344347234311
# Episode 576: Total Reward = 6313.626290772655
# Episode 577: Total Reward = 5727.712128004913
# Episode 578: Total Reward = -297.5853568527084
# Episode 579: Total Reward = 2688.835637985647
# Episode 580: Total Reward = -395.75819193690745
# Episode 581: Total Reward = -705.2114880856535
# Episode 582: Total Reward = 903.4216298215082
# Episode 583: Total Reward = 4559.563059503098
# Episode 584: Total Reward = 11701.686620985229
# Episode 585: Total Reward = 4700.09602722813
# Episode 586: Total Reward = 3385.2366800239724
# Episode 587: Total Reward = 6071.719532025135
# Episode 588: Total Reward = -496.0858705621589
# Episode 589: Total Reward = -281.61789573844857
# Episode 590: Total Reward = 1086.5431347435006
# Episode 591: Total Reward = 1495.7920229838487
# Episode 592: Total Reward = 543.2582187668587
# Episode 593: Total Reward = 7571.293909651389
# Episode 594: Total Reward = 9860.324624889337
# Episode 595: Total Reward = 22175.36261055619
# Episode 596: Total Reward = 4985.05331382205
# Episode 597: Total Reward = 5514.3879086448405
# Episode 598: Total Reward = 4873.128517768865
# Episode 599: Total Reward = 2218.7812699332617
# Episode 600: Total Reward = -851.8440895475406
# Episode 601: Total Reward = -920.7107744399473
# Episode 602: Total Reward = 943.7555632328504
# Episode 603: Total Reward = 5792.7854452320125
# Episode 604: Total Reward = 8351.227537289687
# Episode 605: Total Reward = 6122.168017669573
# Episode 606: Total Reward = 867.3140895419406
# Episode 607: Total Reward = 399.1320827102261
# Episode 608: Total Reward = -177.90252454998316
# Episode 609: Total Reward = 7607.153700204088
# Episode 610: Total Reward = 6377.34726622889
# Episode 611: Total Reward = 13734.950849073864
# Episode 612: Total Reward = 6896.057799303438
# Episode 613: Total Reward = 4119.905375553886
# Episode 614: Total Reward = -792.0070674674579
# Episode 615: Total Reward = -478.12297223169975
# Episode 616: Total Reward = 426.4245716789765
# Episode 617: Total Reward = -202.76105330444875
# Episode 618: Total Reward = 13644.304075656059
# Episode 619: Total Reward = 25008.806970460017
# Episode 620: Total Reward = 2502.7268045255846
# Episode 621: Total Reward = 14078.724439274618
# Episode 622: Total Reward = 6108.569353014462
# Episode 623: Total Reward = 7029.412520834903
# Episode 624: Total Reward = 14067.088133500287
# Episode 625: Total Reward = 17280.638187251854
# Episode 626: Total Reward = 5498.370459204603
# Episode 627: Total Reward = 10280.090792205548
# Episode 628: Total Reward = 2460.174151823032
# Episode 629: Total Reward = 883.3965599487628
# Episode 630: Total Reward = -672.8403501674499
# Episode 631: Total Reward = -69.76502514487677
# Episode 632: Total Reward = 5852.274098642762
# Episode 633: Total Reward = 26052.683393409283
# Episode 634: Total Reward = 15221.39179982968
# Episode 635: Total Reward = 5979.172860658506
# Episode 636: Total Reward = 16774.93739690044
# Episode 637: Total Reward = 14626.761207391832
# Episode 638: Total Reward = 7443.71576129599
# Episode 639: Total Reward = 596.9341893778688
# Episode 640: Total Reward = -1085.031231700456
# Episode 641: Total Reward = -669.8895086165123
# Episode 642: Total Reward = -299.7402587209229
# Episode 643: Total Reward = -408.3985493893105
# Episode 644: Total Reward = 84.38605750518629
# Episode 645: Total Reward = 2057.4097833118526
# Episode 646: Total Reward = -714.6224097112872
# Episode 647: Total Reward = -653.9268039274666
# Episode 648: Total Reward = -718.2085724009801
# Episode 649: Total Reward = -657.5552083305814
# Episode 650: Total Reward = -113.23293581594186
# Episode 651: Total Reward = 1908.6540860196546
# Episode 652: Total Reward = -814.3693555861717
# Episode 653: Total Reward = 2047.3492634242298
# Episode 654: Total Reward = 9566.91892135737
# Episode 655: Total Reward = 22574.766911598974
# Episode 656: Total Reward = 21551.490533298067
# Episode 657: Total Reward = 3992.618547825637
# Episode 658: Total Reward = 8078.000450750497
# Episode 659: Total Reward = 4466.202382509576
# Episode 660: Total Reward = 2775.2975449592786
# Episode 661: Total Reward = 3279.5414015646093
# Episode 662: Total Reward = 10399.562265958037
# Episode 663: Total Reward = -1962.0415181855753
# Episode 664: Total Reward = -810.3781102934295
# Episode 665: Total Reward = -383.40241226185833
# Episode 666: Total Reward = 104.88689024850184
# Episode 667: Total Reward = -631.8501387664675
# Episode 668: Total Reward = -628.2258911981465
# Episode 669: Total Reward = -791.1637699036185
# Episode 670: Total Reward = -196.55967826745126
# Episode 671: Total Reward = 914.5960484017622
# Episode 672: Total Reward = 23090.73242845256
# Episode 673: Total Reward = 10598.460462904353
# Episode 674: Total Reward = 11361.097369531144
# Episode 675: Total Reward = 8149.0847550154
# Episode 676: Total Reward = 12214.152328758686
# Episode 677: Total Reward = 6759.868874361895
# Episode 678: Total Reward = 8187.497810471338
# Episode 679: Total Reward = 15134.920896860287
# Episode 680: Total Reward = 9323.194906367937
# Episode 681: Total Reward = 23301.96944711311
# Episode 682: Total Reward = 8385.220557971945
# Episode 683: Total Reward = 7538.908494835659
# Episode 684: Total Reward = 5443.894272739947
# Episode 685: Total Reward = -890.7403973443687
# Episode 686: Total Reward = -354.0968117605364
# Episode 687: Total Reward = -332.6017542243072
# Episode 688: Total Reward = -100.66558279879249
# Episode 689: Total Reward = 33.996056998859544
# Episode 690: Total Reward = -164.29439601981747
# Episode 691: Total Reward = 2920.008308958886
# Episode 692: Total Reward = 9775.737187811044
# Episode 693: Total Reward = 20864.801028400994
# Episode 694: Total Reward = 30270.129682082334
# Episode 695: Total Reward = 25147.594300399174
# Episode 696: Total Reward = 14328.683179364798
# Episode 697: Total Reward = 6902.83376594509
# Episode 698: Total Reward = 16954.531382323563
# Episode 699: Total Reward = 6622.352311212077
# Episode 700: Total Reward = 5528.635932526975
# Episode 701: Total Reward = 6115.024573457324
# Episode 702: Total Reward = -258.18823930246765
# Episode 703: Total Reward = -766.0928719574083
# Episode 704: Total Reward = -457.87160339852306
# Episode 705: Total Reward = 437.17672635596585
# Episode 706: Total Reward = -191.36298863071596
# Episode 707: Total Reward = 314.8488938637692
# Episode 708: Total Reward = -428.86872389741006
# Episode 709: Total Reward = -425.7339721862309
# Episode 710: Total Reward = -39.5184005925423
# Episode 711: Total Reward = -797.7080358648897
# Episode 712: Total Reward = -266.80897877714494
# Episode 713: Total Reward = 15060.928941826764
# Episode 714: Total Reward = 25644.175963466016
# Episode 715: Total Reward = 12899.149688563377
# Episode 716: Total Reward = 8882.483692355057
# Episode 717: Total Reward = 3708.491025306495
# Episode 718: Total Reward = 20086.233181427157
# Episode 719: Total Reward = 20329.5167429625
# Episode 720: Total Reward = 33756.17194682167
# Episode 721: Total Reward = 4139.0637897395445
# Episode 722: Total Reward = 33509.18480646135
# Episode 723: Total Reward = 12977.527359889496
# Episode 724: Total Reward = 24147.37533889849
# Episode 725: Total Reward = 10927.016612881504
# Episode 726: Total Reward = 5286.835173017431
# Episode 727: Total Reward = 6209.258693626576
# Episode 728: Total Reward = -864.8356033344938
# Episode 729: Total Reward = -900.2335051550881
# Episode 730: Total Reward = -954.8390511934247
# Episode 731: Total Reward = -732.9803822906962
# Episode 732: Total Reward = -625.1015706460939
# Episode 733: Total Reward = -421.48331783979967
# Episode 734: Total Reward = 1273.06523019171
# Episode 735: Total Reward = -0.9005661407693148
# Episode 736: Total Reward = -265.45132663513834
# Episode 737: Total Reward = -345.107383433338
# Episode 738: Total Reward = 910.3031977477549
# Episode 739: Total Reward = 212.5380494278072
# Episode 740: Total Reward = 12997.977430911795
# Episode 741: Total Reward = 7569.051989995476
# Episode 742: Total Reward = 11321.080632248846
# Episode 743: Total Reward = 15640.305333979739
# Episode 744: Total Reward = 17204.07689025309
# Episode 745: Total Reward = 19630.21861354405
# Episode 746: Total Reward = 15294.560034192169
# Episode 747: Total Reward = 18575.482607866914
# Episode 748: Total Reward = 10591.167165554047
# Episode 749: Total Reward = 10576.916842023224
# Episode 750: Total Reward = 12715.214412585554
# Episode 751: Total Reward = 5042.319101311205
# Episode 752: Total Reward = 42453.68416961093
# Episode 753: Total Reward = 26393.093711010668
# Episode 754: Total Reward = 37235.579656353686
# Episode 755: Total Reward = 8987.98353231868
# Episode 756: Total Reward = 25653.360575560855
# Episode 757: Total Reward = 7315.550517813747
# Episode 758: Total Reward = 21263.68328956858
# Episode 759: Total Reward = 15934.199092932928
# Episode 760: Total Reward = 42027.443399582895
# Episode 761: Total Reward = 47461.684168514555
# Episode 762: Total Reward = 5179.462840329814
# Episode 763: Total Reward = 8276.712410022468
# Episode 764: Total Reward = 12213.052896245219
# Episode 765: Total Reward = -403.5301296758644
# Episode 766: Total Reward = -813.4315624498108
# Episode 767: Total Reward = -829.9400045224837
# Episode 768: Total Reward = -1229.973786802047
# Episode 769: Total Reward = -795.7314484659225
# Episode 770: Total Reward = -957.8447561246054
# Episode 771: Total Reward = -290.8833138893954
# Episode 772: Total Reward = -608.1734625043892
# Episode 773: Total Reward = -334.17506972046266
# Episode 774: Total Reward = -175.1700589395382
# Episode 775: Total Reward = 1276.9926843399703
# Episode 776: Total Reward = -836.0258347332228
# Episode 777: Total Reward = -770.9047873708171
# Episode 778: Total Reward = -86.85611399421154
# Episode 779: Total Reward = -643.2168655929661
# Episode 780: Total Reward = -704.0784914348268
# Episode 781: Total Reward = -486.3576448862661
# Episode 782: Total Reward = -848.4009637722224
# Episode 783: Total Reward = -417.42730355955376
# Episode 784: Total Reward = -316.00338441256156
# Episode 785: Total Reward = -784.3558849143018
# Episode 786: Total Reward = 22296.707471697267
# Episode 787: Total Reward = 42195.41051404737
# Episode 788: Total Reward = 13565.61163015755
# Episode 789: Total Reward = 27526.863139371457
# Episode 790: Total Reward = 15486.297325321655
# Episode 791: Total Reward = 25307.792468938653
# Episode 792: Total Reward = 8435.952961631476
# Episode 793: Total Reward = 5916.8355861442815
# Episode 794: Total Reward = 15153.873636759201
# Episode 795: Total Reward = 20763.272503785556
# Episode 796: Total Reward = 15235.564483343283
# Episode 797: Total Reward = 47049.2979874362
# Episode 798: Total Reward = 13840.189540846188
# Episode 799: Total Reward = 23160.30003338298
# Episode 800: Total Reward = 42009.12049441788
# Episode 801: Total Reward = 14293.148651754185
# Episode 802: Total Reward = 36164.15626051504
# Episode 803: Total Reward = 3598.4197202094188
# Episode 804: Total Reward = 10087.788159304202
# Episode 805: Total Reward = 451.7039024521106
# Episode 806: Total Reward = -687.7947303593238
# Episode 807: Total Reward = -548.5858018727869
# Episode 808: Total Reward = -712.9084815420644
# Episode 809: Total Reward = -913.1960502527153
# Episode 810: Total Reward = -432.2014162045199
# Episode 811: Total Reward = 84.42678365884744
# Episode 812: Total Reward = -327.87976927307733
# Episode 813: Total Reward = 11595.488550012618
# Episode 814: Total Reward = 4599.97352455039
# Episode 815: Total Reward = -308.82397668186843
# Episode 816: Total Reward = -965.3665115023381
# Episode 817: Total Reward = -380.5221949637667
# Episode 818: Total Reward = -810.3199341729916
# Episode 819: Total Reward = -566.6672929805452
# Episode 820: Total Reward = -749.669223984599
# Episode 821: Total Reward = -550.8925422903739
# Episode 822: Total Reward = -753.1240252302114
# Episode 823: Total Reward = -817.1701489638747
# Episode 824: Total Reward = -707.8270884198652
# Episode 825: Total Reward = -876.4287489086918
# Episode 826: Total Reward = -724.5128366894686
# Episode 827: Total Reward = -787.3733671768662
# Episode 828: Total Reward = 5107.269656783852
# Episode 829: Total Reward = 26503.310638614526
# Episode 830: Total Reward = 42108.35248435776
# Episode 831: Total Reward = 19102.502238871653
# Episode 832: Total Reward = 13770.412529893427
# Episode 833: Total Reward = 53767.1189491428
# Episode 834: Total Reward = 25526.567053444767
# Episode 835: Total Reward = 12254.659640255766
# Episode 836: Total Reward = 20768.31906312499
# Episode 837: Total Reward = 27893.045581402603
# Episode 838: Total Reward = 41924.34315421423
# Episode 839: Total Reward = 60316.50768146327
# Episode 840: Total Reward = 17325.901364570986
# Episode 841: Total Reward = 5408.276465747282
# Episode 842: Total Reward = 30476.422694045377
# Episode 843: Total Reward = 41990.337523003334
# Episode 844: Total Reward = 32530.735720145192
# Episode 845: Total Reward = 7290.2819858437915
# Episode 846: Total Reward = 20739.689692765744
# Episode 847: Total Reward = 20995.159781935177
# Episode 848: Total Reward = 52035.17131804261
# Episode 849: Total Reward = 6132.794070633461
# Episode 850: Total Reward = 8192.557128331786
# Episode 851: Total Reward = 13775.438531014614
# Episode 852: Total Reward = 20323.7968313765
# Episode 853: Total Reward = -197.5332228155493
# Episode 854: Total Reward = -982.9810451197579
# Episode 855: Total Reward = -881.4703434663071
# Episode 856: Total Reward = -566.9039959063064
# Episode 857: Total Reward = -633.2553704571358
# Episode 858: Total Reward = -850.4976612680911
# Episode 859: Total Reward = 472.90478002097274
# Episode 860: Total Reward = -67.52740029547266
# Episode 861: Total Reward = -524.5215644745899
# Episode 862: Total Reward = -397.7007719824868
# Episode 863: Total Reward = -237.72365400410396
# Episode 864: Total Reward = 1407.6948274410895
# Episode 865: Total Reward = -114.54510364558882
# Episode 866: Total Reward = -106.21319961833687
# Episode 867: Total Reward = 12372.465023231864
# Episode 868: Total Reward = 16440.426226188058
# Episode 869: Total Reward = 25323.674388517353
# Episode 870: Total Reward = 9620.99485724805
# Episode 871: Total Reward = 29591.32761047795
# Episode 872: Total Reward = 41752.29065758805
# Episode 873: Total Reward = 12185.373107873684
# Episode 874: Total Reward = 42193.55307324256
# Episode 875: Total Reward = 13497.716249061992
# Episode 876: Total Reward = 19607.619515166793
# Episode 877: Total Reward = 15788.952469781847
# Episode 878: Total Reward = 13085.586280684593
# Episode 879: Total Reward = 15400.534221702195
# Episode 880: Total Reward = 11719.184081828958
# Episode 881: Total Reward = 10761.699405792133
# Episode 882: Total Reward = 41673.400938535175
# Episode 883: Total Reward = 16709.532947439664
# Episode 884: Total Reward = 13087.053693479702
# Episode 885: Total Reward = 41012.63617614947
# Episode 886: Total Reward = 5667.340969796386
# Episode 887: Total Reward = 52759.30244495877
# Episode 888: Total Reward = 28274.226083361693
# Episode 889: Total Reward = 41525.63010060117
# Episode 890: Total Reward = 8302.808148583958
# Episode 891: Total Reward = 10386.54873544746
# Episode 892: Total Reward = 41701.8735185867
# Episode 893: Total Reward = 16111.882489509306
# Episode 894: Total Reward = 22489.90022748709
# Episode 895: Total Reward = 31931.243437993173
# Episode 896: Total Reward = 15480.06539524233
# Episode 897: Total Reward = 10441.168671506122
# Episode 898: Total Reward = 43079.13240228789
# Episode 899: Total Reward = 42134.74187829716
# Episode 900: Total Reward = 16681.304627503687
# Episode 901: Total Reward = 12384.18049456886
# Episode 902: Total Reward = 41644.42045147837
# Episode 903: Total Reward = 38654.450341958836
# Episode 904: Total Reward = 41972.675867991675
# Episode 905: Total Reward = 15768.907425274934
# Episode 906: Total Reward = 17349.367579744718
# Episode 907: Total Reward = 26537.58079590806
# Episode 908: Total Reward = 39162.25477281389
# Episode 909: Total Reward = 5125.072657191151
# Episode 910: Total Reward = -874.2225933697873
# Episode 911: Total Reward = -767.851794158811
# Episode 912: Total Reward = -1006.5158930182905
# Episode 913: Total Reward = -745.1755091249576
# Episode 914: Total Reward = 19.52207853222149
# Episode 915: Total Reward = -577.7867094683404
# Episode 916: Total Reward = -414.0933743926636
# Episode 917: Total Reward = -510.59160973879085
# Episode 918: Total Reward = -202.45399617155533
# Episode 919: Total Reward = -435.91418721380967
# Episode 920: Total Reward = -340.4350269280303
# Episode 921: Total Reward = -598.2729176040041
# Episode 922: Total Reward = -411.2397933953748
# Episode 923: Total Reward = -725.3400831476289
# Episode 924: Total Reward = -772.0273644983308
# Episode 925: Total Reward = -553.2053182181435
# Episode 926: Total Reward = -797.7478018080753
# Episode 927: Total Reward = -819.4980073532531
# Episode 928: Total Reward = -297.544861642356
# Episode 929: Total Reward = -645.1688949175017
# Episode 930: Total Reward = 156.35264660900074
# Episode 931: Total Reward = -898.7859951652981
# Episode 932: Total Reward = -607.333089781783
# Episode 933: Total Reward = -430.9647148263242
# Episode 934: Total Reward = -511.04566659758973
# Episode 935: Total Reward = -639.9585192441781
# Episode 936: Total Reward = -855.5676520081976
# Episode 937: Total Reward = 1452.54112229025
# Episode 938: Total Reward = 68833.41464205564
# Episode 939: Total Reward = 42191.992528524126
# Episode 940: Total Reward = 24683.507189998774
# Episode 941: Total Reward = 30115.8141032537
# Episode 942: Total Reward = 18006.08030307921
# Episode 943: Total Reward = 54531.57684609376
# Episode 944: Total Reward = 11315.23577970895
# Episode 945: Total Reward = 13169.518934963202
# Episode 946: Total Reward = 42193.55307324256
# Episode 947: Total Reward = 21989.732618014234
# Episode 948: Total Reward = 66154.67784128118
# Episode 949: Total Reward = 41851.29813519816
# Episode 950: Total Reward = 42193.55307324256
# Episode 951: Total Reward = 17987.901110104838
# Episode 952: Total Reward = 14101.475392916349
# Episode 953: Total Reward = 64152.76027117532
# Episode 954: Total Reward = 42203.54448533924
# Episode 955: Total Reward = 26177.88174851278
# Episode 956: Total Reward = 19910.7024339644
# Episode 957: Total Reward = 41922.45506072876
# Episode 958: Total Reward = 19972.27661304415
# Episode 959: Total Reward = 3085.009713881605
# Episode 960: Total Reward = -641.8599788731321
# Episode 961: Total Reward = -729.7702526431548
# Episode 962: Total Reward = -520.459028880602
# Episode 963: Total Reward = -541.3446821843692
# Episode 964: Total Reward = -825.3646474583852
# Episode 965: Total Reward = -880.2102744663844
# Episode 966: Total Reward = -778.3215516616925
# Episode 967: Total Reward = -835.5903138095919
# Episode 968: Total Reward = -347.05259793709064
# Episode 969: Total Reward = -482.66190291435873
# Episode 970: Total Reward = -600.513430866417
# Episode 971: Total Reward = 336.02986929469495
# Episode 972: Total Reward = -433.8628456531287
# Episode 973: Total Reward = -238.62896406388816
# Episode 974: Total Reward = -569.7746815969206
# Episode 975: Total Reward = 1355.7380257665397
# Episode 976: Total Reward = -368.8830412918903
# Episode 977: Total Reward = -480.95239026670043
# Episode 978: Total Reward = 21985.66478757459
# Episode 979: Total Reward = 42193.55307324256
# Episode 980: Total Reward = 42024.93449883452
# Episode 981: Total Reward = 42193.55307324256
# Episode 982: Total Reward = 24931.473711548657
# Episode 983: Total Reward = 42138.35616488776
# Episode 984: Total Reward = 29240.29487989797
# Episode 985: Total Reward = 40883.07658462817
# Episode 986: Total Reward = 7428.354727554955
# Episode 987: Total Reward = 5716.813454439176
# Episode 988: Total Reward = 18583.791187144365
# Episode 989: Total Reward = 10011.055483895576
# Episode 990: Total Reward = 16366.55627904985
# Episode 991: Total Reward = 16430.067964363134
# Episode 992: Total Reward = 25162.731651445778
# Episode 993: Total Reward = 42117.07043920993
# Episode 994: Total Reward = 11496.195009029929
# Episode 995: Total Reward = 10009.45260304744
# Episode 996: Total Reward = 41956.90848975588
# Episode 997: Total Reward = 9033.631221680516
# Episode 998: Total Reward = 53260.28733320437
# Episode 999: Total Reward = 30426.37824090082
# Episode 1000: Total Reward = 58666.91782887628
# ###############################################
#             Trained Q-Table:
# ###############################################
# [[6026.20900929 1646.58679584 1900.70880088]
#  [5314.47874276 5039.10348683 8827.90434072]
#  [4078.89125071 1680.44539392 1683.02977454]
#  [4311.10476211 3071.39636053 7986.85932016]]

# %% [markdown]
# ## Running the Q-Learning for 100 days

# %%
q_learning(num_episodes=1000, alpha=0.1, gamma=0.99, epsilon=1.0, epsilon_decay=0.995, epsilon_min=0.01, training=False)
# Out:
# Episode 1: Total Reward = -1230.2976372544042
# Episode 2: Total Reward = -1362.2151973121938
# Episode 3: Total Reward = -1730.1697758047264
# Episode 4: Total Reward = -1979.0964518867938
# Episode 5: Total Reward = -1716.8964287453098
# Episode 6: Total Reward = -1839.542166042488
# Episode 7: Total Reward = -1670.6950174368606
# Episode 8: Total Reward = -1480.8757529904615
# Episode 9: Total Reward = -1582.0086412441635
# Episode 10: Total Reward = -1716.7073738938825
# Episode 11: Total Reward = -1620.1856238014925
# Episode 12: Total Reward = -1688.4441913159744
# Episode 13: Total Reward = -1625.7664186537459
# Episode 14: Total Reward = -1949.9546354269874
# Episode 15: Total Reward = -1800.0649137130295
# Episode 16: Total Reward = -1503.4627552628262
# Episode 17: Total Reward = -1831.9586599474105
# Episode 18: Total Reward = -1494.0622151251014
# Episode 19: Total Reward = -1336.5644958006892
# Episode 20: Total Reward = -1496.844666432839
# Episode 21: Total Reward = -1509.4719318512155
# Episode 22: Total Reward = -1604.7700862388156
# Episode 23: Total Reward = -1695.8447332327614
# Episode 24: Total Reward = -1489.7926781397773
# Episode 25: Total Reward = -1514.4403643981075
# Episode 26: Total Reward = -1635.8017983549973
# Episode 27: Total Reward = -1441.8122252283526
# Episode 28: Total Reward = -1793.510528153914
# Episode 29: Total Reward = -1470.4575894204722
# Episode 30: Total Reward = -1917.6550892773346
# Episode 31: Total Reward = -1300.3337864590037
# Episode 32: Total Reward = -1466.3991390047136
# Episode 33: Total Reward = -1566.6130481851708
# Episode 34: Total Reward = -1477.4301424495834
# Episode 35: Total Reward = -1579.653532025585
# Episode 36: Total Reward = -1605.6841138558955
# Episode 37: Total Reward = -1452.1954910508305
# Episode 38: Total Reward = -1406.8075949811139
# Episode 39: Total Reward = -1366.0540424368266
# Episode 40: Total Reward = -1510.5453805967309
# Episode 41: Total Reward = -1425.02278494952
# Episode 42: Total Reward = -1673.6723673360323
# Episode 43: Total Reward = -1634.4339510094205
# Episode 44: Total Reward = -1633.752426038705
# Episode 45: Total Reward = -1543.3133106169319
# Episode 46: Total Reward = -1504.499651678215
# Episode 47: Total Reward = -1253.4495123519787
# Episode 48: Total Reward = -1314.5903078227016
# Episode 49: Total Reward = -1455.2934861561068
# Episode 50: Total Reward = -1211.2892736342742
# Episode 51: Total Reward = -1518.6023188739562
# Episode 52: Total Reward = -1378.1084824384832
# Episode 53: Total Reward = -1718.2641875875877
# Episode 54: Total Reward = -1526.360414817998
# Episode 55: Total Reward = -1559.5143398273115
# Episode 56: Total Reward = -1528.635766435254
# Episode 57: Total Reward = -1542.491141041407
# Episode 58: Total Reward = -1668.7644883639932
# Episode 59: Total Reward = -1672.6666217841425
# Episode 60: Total Reward = -1211.639363681544
# Episode 61: Total Reward = -1115.778048897976
# Episode 62: Total Reward = -1403.3774505813283
# Episode 63: Total Reward = -1682.719674694251
# Episode 64: Total Reward = -1263.083369426603
# Episode 65: Total Reward = -1301.55924856353
# Episode 66: Total Reward = -1250.1913599595873
# Episode 67: Total Reward = -1836.4740926561697
# Episode 68: Total Reward = -1432.8891092342253
# Episode 69: Total Reward = -1183.461433722741
# Episode 70: Total Reward = -1589.1978206253182
# Episode 71: Total Reward = -1333.2343228844986
# Episode 72: Total Reward = -1384.9408925691166
# Episode 73: Total Reward = -1461.8622289746172
# Episode 74: Total Reward = -1211.3368336134574
# Episode 75: Total Reward = -1655.4450813909452
# Episode 76: Total Reward = -1059.66643457584
# Episode 77: Total Reward = -1791.2621290787706
# Episode 78: Total Reward = -1225.3891283498992
# Episode 79: Total Reward = -1254.6277106990042
# Episode 80: Total Reward = -1556.2807702529117
# Episode 81: Total Reward = -1448.5372013381984
# Episode 82: Total Reward = -1365.9141382593123
# Episode 83: Total Reward = -1673.434607400698
# Episode 84: Total Reward = -1371.8453252107056
# Episode 85: Total Reward = -1647.8603044112976
# Episode 86: Total Reward = -1024.1977268842159
# Episode 87: Total Reward = -1217.8746454784352
# Episode 88: Total Reward = -1548.157221729573
# Episode 89: Total Reward = -1478.743360243712
# Episode 90: Total Reward = -1265.244383397643
# Episode 91: Total Reward = -1283.0868021295666
# Episode 92: Total Reward = -843.5499043110883
# Episode 93: Total Reward = -1080.6258580663439
# Episode 94: Total Reward = -1195.0151983470384
# Episode 95: Total Reward = -888.7760637496812
# Episode 96: Total Reward = -1260.8785901097401
# Episode 97: Total Reward = -1667.1663498025496
# Episode 98: Total Reward = -1078.8375850478042
# Episode 99: Total Reward = -1317.1377769268593
# Episode 100: Total Reward = -1214.0193024940938
# Episode 101: Total Reward = -1354.398572162396
# Episode 102: Total Reward = -1272.2586436923489
# Episode 103: Total Reward = -1376.5191818357105
# Episode 104: Total Reward = -1300.2419362306591
# Episode 105: Total Reward = -1270.789233074658
# Episode 106: Total Reward = -1330.221408590767
# Episode 107: Total Reward = -1072.5044840719358
# Episode 108: Total Reward = -1644.6686804930273
# Episode 109: Total Reward = -1573.7455586369294
# Episode 110: Total Reward = -1398.6069282256458
# Episode 111: Total Reward = -1320.2547648866
# Episode 112: Total Reward = -1280.3730208063391
# Episode 113: Total Reward = -982.7594133030193
# Episode 114: Total Reward = -1437.9569564168696
# Episode 115: Total Reward = -1250.613775303723
# Episode 116: Total Reward = -1399.910611414527
# Episode 117: Total Reward = -1195.7176316577911
# Episode 118: Total Reward = -1114.646991850468
# Episode 119: Total Reward = -1189.987442650417
# Episode 120: Total Reward = -1165.3708364576983
# Episode 121: Total Reward = -1055.0324134375655
# Episode 122: Total Reward = -1272.4420833603049
# Episode 123: Total Reward = -533.7474315975642
# Episode 124: Total Reward = -1410.897141621418
# Episode 125: Total Reward = -1354.9638571439211
# Episode 126: Total Reward = -893.5757534169942
# Episode 127: Total Reward = -1332.5397376975209
# Episode 128: Total Reward = -1450.7424307244942
# Episode 129: Total Reward = -987.1982058348062
# Episode 130: Total Reward = -820.0762298835984
# Episode 131: Total Reward = -1257.7599097930151
# Episode 132: Total Reward = -1151.8779227410193
# Episode 133: Total Reward = -1302.359112742454
# Episode 134: Total Reward = -1171.385670035477
# Episode 135: Total Reward = -1153.7022043138547
# Episode 136: Total Reward = -1091.6166787957002
# Episode 137: Total Reward = -1219.7613398426095
# Episode 138: Total Reward = -915.5023021172759
# Episode 139: Total Reward = -1215.3267541893877
# Episode 140: Total Reward = -723.314964688386
# Episode 141: Total Reward = -1217.3778814996251
# Episode 142: Total Reward = -1151.5331379075128
# Episode 143: Total Reward = -1297.1685535322654
# Episode 144: Total Reward = -959.8353089708296
# Episode 145: Total Reward = -1096.545590061404
# Episode 146: Total Reward = -857.3271771553827
# Episode 147: Total Reward = -1138.085463629135
# Episode 148: Total Reward = -976.086340369152
# Episode 149: Total Reward = -949.4428383857767
# Episode 150: Total Reward = -995.8929119575919
# Episode 151: Total Reward = -751.8889484912014
# Episode 152: Total Reward = -1341.3759578499605
# Episode 153: Total Reward = -1290.423367134294
# Episode 154: Total Reward = -1341.3643307011107
# Episode 155: Total Reward = -1084.4312588545547
# Episode 156: Total Reward = -1022.1163902058914
# Episode 157: Total Reward = -1344.3223242060824
# Episode 158: Total Reward = -742.9497743734846
# Episode 159: Total Reward = -1283.3376684077489
# Episode 160: Total Reward = -1200.8922061001808
# Episode 161: Total Reward = -939.3454645483496
# Episode 162: Total Reward = -1107.5054279766487
# Episode 163: Total Reward = -904.0585197219528
# Episode 164: Total Reward = -1099.783272282511
# Episode 165: Total Reward = -1090.163280884164
# Episode 166: Total Reward = -1168.353347637972
# Episode 167: Total Reward = -1117.1901205897304
# Episode 168: Total Reward = -614.8860517932591
# Episode 169: Total Reward = -1286.8393673310388
# Episode 170: Total Reward = -1357.3804972514686
# Episode 171: Total Reward = -1035.9269851860229
# Episode 172: Total Reward = -1155.2966034386245
# Episode 173: Total Reward = -975.6388776430761
# Episode 174: Total Reward = -1078.6679507780132
# Episode 175: Total Reward = -39.65594565732678
# Episode 176: Total Reward = -1116.2257856983615
# Episode 177: Total Reward = -885.6714771481239
# Episode 178: Total Reward = -1222.978191427519
# Episode 179: Total Reward = -714.8312532923719
# Episode 180: Total Reward = -708.5485254192092
# Episode 181: Total Reward = -817.0890967219996
# Episode 182: Total Reward = -890.1605803600503
# Episode 183: Total Reward = -893.3880706487807
# Episode 184: Total Reward = -1030.8713489183133
# Episode 185: Total Reward = -570.9794680140246
# Episode 186: Total Reward = -637.0991626717079
# Episode 187: Total Reward = -854.6257283663753
# Episode 188: Total Reward = -1021.0128294295766
# Episode 189: Total Reward = -526.9636723376632
# Episode 190: Total Reward = -1234.2434397947131
# Episode 191: Total Reward = -1002.140925145035
# Episode 192: Total Reward = -905.8158028141786
# Episode 193: Total Reward = -479.73878705745227
# Episode 194: Total Reward = -280.49025922551766
# Episode 195: Total Reward = -793.0382023472766
# Episode 196: Total Reward = -1187.1845225270904
# Episode 197: Total Reward = -1336.8764741716097
# Episode 198: Total Reward = 371.37592826521046
# Episode 199: Total Reward = -1096.755697977364
# Episode 200: Total Reward = -1047.9836024110073
# Episode 201: Total Reward = -1052.1024311732258
# Episode 202: Total Reward = -957.3552289011936
# Episode 203: Total Reward = -931.4636967486337
# Episode 204: Total Reward = -910.9050611924001
# Episode 205: Total Reward = -798.6674151596343
# Episode 206: Total Reward = -948.1030885872512
# Episode 207: Total Reward = -916.6084150230492
# Episode 208: Total Reward = -1095.9632132484546
# Episode 209: Total Reward = -819.0496070259047
# Episode 210: Total Reward = -693.1052622811507
# Episode 211: Total Reward = -1002.1258725964443
# Episode 212: Total Reward = -667.1974517856625
# Episode 213: Total Reward = -920.0051736136336
# Episode 214: Total Reward = -559.9367049348449
# Episode 215: Total Reward = -634.516735053752
# Episode 216: Total Reward = -757.9353196208892
# Episode 217: Total Reward = -926.9181649658316
# Episode 218: Total Reward = -158.6259924996934
# Episode 219: Total Reward = -815.4641891591169
# Episode 220: Total Reward = -655.7213015896197
# Episode 221: Total Reward = -1121.8508406422811
# Episode 222: Total Reward = -843.5912261529271
# Episode 223: Total Reward = -656.1824167798256
# Episode 224: Total Reward = -614.1977186360518
# Episode 225: Total Reward = -739.4287524262623
# Episode 226: Total Reward = -525.1805660118196
# Episode 227: Total Reward = -484.69938362663055
# Episode 228: Total Reward = -731.5125896559172
# Episode 229: Total Reward = -92.84306325244233
# Episode 230: Total Reward = -387.71584107794763
# Episode 231: Total Reward = -520.1368445141218
# Episode 232: Total Reward = -1245.776762908422
# Episode 233: Total Reward = -792.4934213138857
# Episode 234: Total Reward = -566.5936539497875
# Episode 235: Total Reward = -831.2797896672291
# Episode 236: Total Reward = -865.2359059187474
# Episode 237: Total Reward = -828.6468184414616
# Episode 238: Total Reward = -642.1190869500322
# Episode 239: Total Reward = -1213.7725884706297
# Episode 240: Total Reward = -1104.9632224205077
# Episode 241: Total Reward = -835.727867797992
# Episode 242: Total Reward = -636.4823890695334
# Episode 243: Total Reward = -794.8868966703724
# Episode 244: Total Reward = -279.06043880101566
# Episode 245: Total Reward = -876.1772989895403
# Episode 246: Total Reward = -1248.0300107102646
# Episode 247: Total Reward = -677.3648902227636
# Episode 248: Total Reward = -19.169073384720765
# Episode 249: Total Reward = -1141.8093643858278
# Episode 250: Total Reward = 1381.119308054339
# Episode 251: Total Reward = -1040.9416358223293
# Episode 252: Total Reward = -162.8042156520747
# Episode 253: Total Reward = -586.8997885647829
# Episode 254: Total Reward = -1192.1613752353123
# Episode 255: Total Reward = -567.3604013221975
# Episode 256: Total Reward = 14.75113467831018
# Episode 257: Total Reward = -891.0257807600175
# Episode 258: Total Reward = -501.7481008254172
# Episode 259: Total Reward = 103.49247032708682
# Episode 260: Total Reward = 910.0010559235263
# Episode 261: Total Reward = -1107.9678419998527
# Episode 262: Total Reward = 898.057529774587
# Episode 263: Total Reward = -406.0491606063437
# Episode 264: Total Reward = -433.0750142312031
# Episode 265: Total Reward = -881.9462454326543
# Episode 266: Total Reward = -662.6799965058249
# Episode 267: Total Reward = -724.5999222347724
# Episode 268: Total Reward = -904.0227285375229
# Episode 269: Total Reward = -1248.5690871777574
# Episode 270: Total Reward = -755.6338576371811
# Episode 271: Total Reward = -920.2421720285365
# Episode 272: Total Reward = -606.0242195399608
# Episode 273: Total Reward = -34.37302812510417
# Episode 274: Total Reward = -483.5282006753235
# Episode 275: Total Reward = -864.2732496183548
# Episode 276: Total Reward = -405.85269185934635
# Episode 277: Total Reward = -600.2573847015467
# Episode 278: Total Reward = 173.67702807797576
# Episode 279: Total Reward = -595.7064379537679
# Episode 280: Total Reward = -738.2752720557298
# Episode 281: Total Reward = -472.0599004405464
# Episode 282: Total Reward = -237.54076803364407
# Episode 283: Total Reward = -467.8114853602862
# Episode 284: Total Reward = -369.9638123443617
# Episode 285: Total Reward = -893.167898588192
# Episode 286: Total Reward = -631.2286797094602
# Episode 287: Total Reward = -736.2478103155748
# Episode 288: Total Reward = -804.5753533832246
# Episode 289: Total Reward = -634.7985493549837
# Episode 290: Total Reward = -256.566549346561
# Episode 291: Total Reward = -507.2819823257458
# Episode 292: Total Reward = -497.46238760365696
# Episode 293: Total Reward = -829.6896097108523
# Episode 294: Total Reward = -365.1663938249972
# Episode 295: Total Reward = 888.4064695960337
# Episode 296: Total Reward = -171.1871800389344
# Episode 297: Total Reward = 524.824201980536
# Episode 298: Total Reward = -757.8140860819611
# Episode 299: Total Reward = -633.7769376661464
# Episode 300: Total Reward = -328.7678790146392
# Episode 301: Total Reward = -705.076086565671
# Episode 302: Total Reward = -672.9128172852941
# Episode 303: Total Reward = -555.2635804357585
# Episode 304: Total Reward = -436.672755784242
# Episode 305: Total Reward = -755.6776543258811
# Episode 306: Total Reward = -554.7918221645518
# Episode 307: Total Reward = -552.6254944062671
# Episode 308: Total Reward = 738.4661455149125
# Episode 309: Total Reward = -224.2098747649756
# Episode 310: Total Reward = 1088.2918940061518
# Episode 311: Total Reward = -247.49153713278747
# Episode 312: Total Reward = -613.6521832220452
# Episode 313: Total Reward = -406.47901270922824
# Episode 314: Total Reward = 124.42648081829334
# Episode 315: Total Reward = -138.1158629384691
# Episode 316: Total Reward = -743.2137475111452
# Episode 317: Total Reward = -297.0482546549665
# Episode 318: Total Reward = -398.2070491376045
# Episode 319: Total Reward = -356.11720125789435
# Episode 320: Total Reward = -549.5832122391879
# Episode 321: Total Reward = -640.6168161225307
# Episode 322: Total Reward = -128.5727904375712
# Episode 323: Total Reward = -334.15058246750186
# Episode 324: Total Reward = -599.0801906887217
# Episode 325: Total Reward = -205.555025358639
# Episode 326: Total Reward = -248.9200060922875
# Episode 327: Total Reward = -430.92108476888905
# Episode 328: Total Reward = 648.1765192943492
# Episode 329: Total Reward = 578.2378623748382
# Episode 330: Total Reward = -529.1754880262507
# Episode 331: Total Reward = -83.16057096515716
# Episode 332: Total Reward = 748.5674741450965
# Episode 333: Total Reward = -204.43285298034957
# Episode 334: Total Reward = -378.74627934964036
# Episode 335: Total Reward = 390.6683444580199
# Episode 336: Total Reward = -190.81570355372838
# Episode 337: Total Reward = -195.4346397228163
# Episode 338: Total Reward = -299.91041116668976
# Episode 339: Total Reward = 348.12035680351033
# Episode 340: Total Reward = -229.87041067478708
# Episode 341: Total Reward = -345.4516959843271
# Episode 342: Total Reward = 466.94384173919354
# Episode 343: Total Reward = -593.4099480514243
# Episode 344: Total Reward = 328.60802637539314
# Episode 345: Total Reward = -226.8695088438349
# Episode 346: Total Reward = -46.34365288793006
# Episode 347: Total Reward = -314.6449290221508
# Episode 348: Total Reward = -597.3194699914865
# Episode 349: Total Reward = 947.8644420362718
# Episode 350: Total Reward = -344.18318900839705
# Episode 351: Total Reward = -377.3031477223449
# Episode 352: Total Reward = 132.37996297564683
# Episode 353: Total Reward = -277.6834385118663
# Episode 354: Total Reward = 782.2970516464362
# Episode 355: Total Reward = 315.5651684062411
# Episode 356: Total Reward = 104.35171201491946
# Episode 357: Total Reward = -163.85889446472513
# Episode 358: Total Reward = 423.65426817031283
# Episode 359: Total Reward = -754.7118882103593
# Episode 360: Total Reward = 394.3070805719625
# Episode 361: Total Reward = 5.4238571393516395
# Episode 362: Total Reward = -257.53037659396955
# Episode 363: Total Reward = 901.5097677998847
# Episode 364: Total Reward = 1394.496831628403
# Episode 365: Total Reward = -354.7208840499614
# Episode 366: Total Reward = 217.53057722541408
# Episode 367: Total Reward = -152.23802961917798
# Episode 368: Total Reward = -386.72740825037465
# Episode 369: Total Reward = 350.7447898674313
# Episode 370: Total Reward = 1019.7180221626509
# Episode 371: Total Reward = -370.91184166574834
# Episode 372: Total Reward = 42.4002171731001
# Episode 373: Total Reward = 4.547361963714048
# Episode 374: Total Reward = 252.58927327012245
# Episode 375: Total Reward = 672.4891548376065
# Episode 376: Total Reward = 1200.6135798259577
# Episode 377: Total Reward = -485.3936444164575
# Episode 378: Total Reward = -164.21972137741705
# Episode 379: Total Reward = -232.63147104382918
# Episode 380: Total Reward = -535.3925058529628
# Episode 381: Total Reward = -43.893362379389814
# Episode 382: Total Reward = -645.8888565577106
# Episode 383: Total Reward = -688.4342969958018
# Episode 384: Total Reward = -315.91868358140584
# Episode 385: Total Reward = -112.54280275829474
# Episode 386: Total Reward = -418.92219725740995
# Episode 387: Total Reward = 516.5336663763679
# Episode 388: Total Reward = 123.32646063904468
# Episode 389: Total Reward = 2296.2656745083045
# Episode 390: Total Reward = 894.0298689983376
# Episode 391: Total Reward = 309.5087123218271
# Episode 392: Total Reward = -192.40636808212432
# Episode 393: Total Reward = -195.6390122237209
# Episode 394: Total Reward = -154.7488265324741
# Episode 395: Total Reward = 590.1872604060999
# Episode 396: Total Reward = -328.8861711509194
# Episode 397: Total Reward = -145.8913890858508
# Episode 398: Total Reward = 84.52499598459991
# Episode 399: Total Reward = 393.8206059787204
# Episode 400: Total Reward = 2024.5539793280402
# Episode 401: Total Reward = 543.2749202604215
# Episode 402: Total Reward = -400.3336321589323
# Episode 403: Total Reward = 97.83363236149503
# Episode 404: Total Reward = 1322.6240077974749
# Episode 405: Total Reward = -284.97529246028597
# Episode 406: Total Reward = -727.810046013869
# Episode 407: Total Reward = -797.1783710707649
# Episode 408: Total Reward = 1028.2120648590906
# Episode 409: Total Reward = 1923.1572976720715
# Episode 410: Total Reward = -239.1254564959243
# Episode 411: Total Reward = 737.6378193766594
# Episode 412: Total Reward = 1393.6973616698822
# Episode 413: Total Reward = 838.7163124187139
# Episode 414: Total Reward = 515.0165852502946
# Episode 415: Total Reward = -223.87688347672457
# Episode 416: Total Reward = 343.55784431549375
# Episode 417: Total Reward = 496.5669167109725
# Episode 418: Total Reward = -69.07072730706953
# Episode 419: Total Reward = -332.13978238401614
# Episode 420: Total Reward = 407.1198889878941
# Episode 421: Total Reward = 305.5898568486691
# Episode 422: Total Reward = -75.02274547888798
# Episode 423: Total Reward = 1340.9105485148395
# Episode 424: Total Reward = 223.51692258416526
# Episode 425: Total Reward = 1855.2860251481952
# Episode 426: Total Reward = -65.59233715668188
# Episode 427: Total Reward = 1583.8844976805497
# Episode 428: Total Reward = 302.2701838026993
# Episode 429: Total Reward = 1540.2134934125136
# Episode 430: Total Reward = 786.3688591312249
# Episode 431: Total Reward = -98.05143741507422
# Episode 432: Total Reward = -207.29946918787346
# Episode 433: Total Reward = 728.3719242932518
# Episode 434: Total Reward = -458.5660210843531
# Episode 435: Total Reward = 402.01825490398267
# Episode 436: Total Reward = -91.11135035475075
# Episode 437: Total Reward = 244.76631539116963
# Episode 438: Total Reward = -262.0554765265783
# Episode 439: Total Reward = 608.4563128220057
# Episode 440: Total Reward = 1448.5577832738973
# Episode 441: Total Reward = 449.3189252939677
# Episode 442: Total Reward = 1035.7420364186755
# Episode 443: Total Reward = 1311.2157214515696
# Episode 444: Total Reward = 1900.6341631197502
# Episode 445: Total Reward = 611.1811758749939
# Episode 446: Total Reward = 1718.220260501957
# Episode 447: Total Reward = 1521.9649466923115
# Episode 448: Total Reward = 54.6962728460107
# Episode 449: Total Reward = -172.88426133331558
# Episode 450: Total Reward = -146.12976608596216
# Episode 451: Total Reward = -533.3467387225731
# Episode 452: Total Reward = 703.7521919689812
# Episode 453: Total Reward = 6.505672215231231
# Episode 454: Total Reward = 471.40209093247887
# Episode 455: Total Reward = 549.4979565567471
# Episode 456: Total Reward = 1599.4795443582548
# Episode 457: Total Reward = 1365.351410339728
# Episode 458: Total Reward = -459.3132455588873
# Episode 459: Total Reward = 100.24599841427778
# Episode 460: Total Reward = 505.38631232803795
# Episode 461: Total Reward = 323.4874923309901
# Episode 462: Total Reward = 516.2056916728059
# Episode 463: Total Reward = -330.7433616533082
# Episode 464: Total Reward = -26.909939034436935
# Episode 465: Total Reward = 1019.509334168443
# Episode 466: Total Reward = 1458.0787439674793
# Episode 467: Total Reward = 2188.181242073635
# Episode 468: Total Reward = 1535.7318586191927
# Episode 469: Total Reward = 465.25203386251457
# Episode 470: Total Reward = 1747.9116956121388
# Episode 471: Total Reward = 827.8502055462168
# Episode 472: Total Reward = 679.2230335109693
# Episode 473: Total Reward = 51.22416915836075
# Episode 474: Total Reward = 1422.4624529500213
# Episode 475: Total Reward = 1729.3173762669999
# Episode 476: Total Reward = 475.5758224416025
# Episode 477: Total Reward = 760.1982462235496
# Episode 478: Total Reward = 1187.7600774088962
# Episode 479: Total Reward = 71.606790681905
# Episode 480: Total Reward = 306.0655858789143
# Episode 481: Total Reward = 1295.9652711554031
# Episode 482: Total Reward = 806.7582007828228
# Episode 483: Total Reward = 1231.4904772265838
# Episode 484: Total Reward = 1152.2845987145697
# Episode 485: Total Reward = 998.3402166368197
# Episode 486: Total Reward = 671.0399592536168
# Episode 487: Total Reward = 1215.7784430355928
# Episode 488: Total Reward = 959.5772296287039
# Episode 489: Total Reward = 1698.3242424939592
# Episode 490: Total Reward = 1009.9035780089121
# Episode 491: Total Reward = 183.67356270635847
# Episode 492: Total Reward = -97.63696806924693
# Episode 493: Total Reward = 111.79108065609354
# Episode 494: Total Reward = -21.081081820848468
# Episode 495: Total Reward = 204.40298835096047
# Episode 496: Total Reward = -165.52055513066298
# Episode 497: Total Reward = 1132.5016230034505
# Episode 498: Total Reward = -331.0444064806244
# Episode 499: Total Reward = 193.9249531924315
# Episode 500: Total Reward = 1410.5622013076668
# Episode 501: Total Reward = 1812.4783365997118
# Episode 502: Total Reward = 160.06341504137131
# Episode 503: Total Reward = 95.85537003773797
# Episode 504: Total Reward = -462.8231114036932
# Episode 505: Total Reward = 893.073550460381
# Episode 506: Total Reward = 389.96632774079666
# Episode 507: Total Reward = 1374.0334715902695
# Episode 508: Total Reward = 469.37498565298364
# Episode 509: Total Reward = 258.575428589781
# Episode 510: Total Reward = 269.6081493051722
# Episode 511: Total Reward = 707.00146582047
# Episode 512: Total Reward = 847.9553831061959
# Episode 513: Total Reward = 1040.3059863424842
# Episode 514: Total Reward = -459.1739211489253
# Episode 515: Total Reward = 11.438716965592626
# Episode 516: Total Reward = -26.360166436526058
# Episode 517: Total Reward = 1263.8936122815446
# Episode 518: Total Reward = 526.5267812667802
# Episode 519: Total Reward = -186.78253471452024
# Episode 520: Total Reward = 481.4408405774569
# Episode 521: Total Reward = 1052.1045518637573
# Episode 522: Total Reward = 518.4029160537796
# Episode 523: Total Reward = 1477.1715185635135
# Episode 524: Total Reward = 1291.4711121535524
# Episode 525: Total Reward = -104.06374644054071
# Episode 526: Total Reward = 1491.4548772157393
# Episode 527: Total Reward = 1832.8635338778315
# Episode 528: Total Reward = 299.6811263421451
# Episode 529: Total Reward = 1771.503839695066
# Episode 530: Total Reward = 416.7192176032601
# Episode 531: Total Reward = 1918.6429046359126
# Episode 532: Total Reward = 1696.6672017345688
# Episode 533: Total Reward = 894.6674674125309
# Episode 534: Total Reward = 1157.8203781127881
# Episode 535: Total Reward = 275.46937652857025
# Episode 536: Total Reward = 1563.6874614158733
# Episode 537: Total Reward = 412.5511879403924
# Episode 538: Total Reward = 563.5203041942432
# Episode 539: Total Reward = 63.4838103003671
# Episode 540: Total Reward = 1074.2137432465402
# Episode 541: Total Reward = 1983.7654158518335
# Episode 542: Total Reward = 1509.914440849145
# Episode 543: Total Reward = 534.614661709196
# Episode 544: Total Reward = 668.955293827294
# Episode 545: Total Reward = 1048.2886248617715
# Episode 546: Total Reward = 1322.758445143599
# Episode 547: Total Reward = 1028.085809188452
# Episode 548: Total Reward = 325.18697244220385
# Episode 549: Total Reward = 254.87512865132152
# Episode 550: Total Reward = 573.3873778249284
# Episode 551: Total Reward = 1331.3082373427414
# Episode 552: Total Reward = 915.4306740429806
# Episode 553: Total Reward = -105.12759411524493
# Episode 554: Total Reward = -121.54395849089076
# Episode 555: Total Reward = 334.92067724320464
# Episode 556: Total Reward = 359.1167635224743
# Episode 557: Total Reward = 248.96984416792478
# Episode 558: Total Reward = 1801.5486966524777
# Episode 559: Total Reward = 950.3779277007085
# Episode 560: Total Reward = -101.93111025531834
# Episode 561: Total Reward = 1862.9003543080626
# Episode 562: Total Reward = 375.34228945471386
# Episode 563: Total Reward = -158.70990520730902
# Episode 564: Total Reward = 935.5003657784985
# Episode 565: Total Reward = 1924.921519613481
# Episode 566: Total Reward = 291.3807496926355
# Episode 567: Total Reward = 359.62492784502047
# Episode 568: Total Reward = 1782.0199963896644
# Episode 569: Total Reward = 1046.0663476151642
# Episode 570: Total Reward = 231.1360116374017
# Episode 571: Total Reward = 1796.7425238697788
# Episode 572: Total Reward = 198.40638938252087
# Episode 573: Total Reward = 1476.0928580681002
# Episode 574: Total Reward = 1983.7654158518335
# Episode 575: Total Reward = 1879.0645797647455
# Episode 576: Total Reward = 1489.6033808306813
# Episode 577: Total Reward = 1919.583891636948
# Episode 578: Total Reward = 381.0755428385569
# Episode 579: Total Reward = 1918.0631301046806
# Episode 580: Total Reward = 1383.2936015628557
# Episode 581: Total Reward = 455.79235198248705
# Episode 582: Total Reward = 898.6695620158341
# Episode 583: Total Reward = 865.5940526088294
# Episode 584: Total Reward = 1434.2480054970836
# Episode 585: Total Reward = 484.89075868255003
# Episode 586: Total Reward = 322.14045060883393
# Episode 587: Total Reward = 15.205857206025527
# Episode 588: Total Reward = 1866.0120579776822
# Episode 589: Total Reward = 273.7638281189741
# Episode 590: Total Reward = 1671.5457323191483
# Episode 591: Total Reward = -29.934110200177507
# Episode 592: Total Reward = 695.0086717405516
# Episode 593: Total Reward = 1945.966038191647
# Episode 594: Total Reward = 971.1808086757881
# Episode 595: Total Reward = 61.26094041678704
# Episode 596: Total Reward = 692.8694933678173
# Episode 597: Total Reward = 1983.7654158518335
# Episode 598: Total Reward = 1924.921519613481
# Episode 599: Total Reward = 643.5514260854388
# Episode 600: Total Reward = 1983.7654158518335
# Episode 601: Total Reward = 412.75161908232866
# Episode 602: Total Reward = 2082.607119027231
# Episode 603: Total Reward = 539.1443976713916
# Episode 604: Total Reward = 1909.5769929828584
# Episode 605: Total Reward = 1602.051794449122
# Episode 606: Total Reward = 1654.407304293855
# Episode 607: Total Reward = 1983.7654158518335
# Episode 608: Total Reward = 1547.6053910540304
# Episode 609: Total Reward = -111.75912069971571
# Episode 610: Total Reward = 1897.2830916377686
# Episode 611: Total Reward = 1926.014349476589
# Episode 612: Total Reward = 1983.7654158518335
# Episode 613: Total Reward = 1433.959828062131
# Episode 614: Total Reward = 205.84560802845007
# Episode 615: Total Reward = 302.3630397967495
# Episode 616: Total Reward = 1872.0974048084652
# Episode 617: Total Reward = 157.68286047623093
# Episode 618: Total Reward = 1934.4234199930966
# Episode 619: Total Reward = 1932.525338778326
# Episode 620: Total Reward = 713.8003971666625
# Episode 621: Total Reward = 1835.8387732006222
# Episode 622: Total Reward = 1983.7654158518335
# Episode 623: Total Reward = 1983.7654158518335
# Episode 624: Total Reward = 1040.99443544437
# Episode 625: Total Reward = 1392.3425314969852
# Episode 626: Total Reward = 1983.0395490624624
# Episode 627: Total Reward = 1020.4153067343107
# Episode 628: Total Reward = 1818.233655198521
# Episode 629: Total Reward = 1927.5328114574932
# Episode 630: Total Reward = 2138.3186280256004
# Episode 631: Total Reward = 1473.9797088776522
# Episode 632: Total Reward = 1857.1347716221414
# Episode 633: Total Reward = 1643.3845159124544
# Episode 634: Total Reward = 1983.7654158518335
# Episode 635: Total Reward = 1883.5687104566878
# Episode 636: Total Reward = 17.81267888406441
# Episode 637: Total Reward = 487.8861762199839
# Episode 638: Total Reward = 700.5237096050786
# Episode 639: Total Reward = 1983.7654158518335
# Episode 640: Total Reward = 1983.7654158518335
# Episode 641: Total Reward = 511.51402418068983
# Episode 642: Total Reward = 1940.6514126308512
# Episode 643: Total Reward = 426.389447863521
# Episode 644: Total Reward = 1906.2030070171386
# Episode 645: Total Reward = 716.5507825540976
# Episode 646: Total Reward = 1888.5014172322544
# Episode 647: Total Reward = 371.88690591815396
# Episode 648: Total Reward = 1743.177701183527
# Episode 649: Total Reward = 1902.5340313562888
# Episode 650: Total Reward = 407.51273662635555
# Episode 651: Total Reward = 77.23469762820338
# Episode 652: Total Reward = 1852.4758736914746
# Episode 653: Total Reward = 2288.8088087635647
# Episode 654: Total Reward = 1983.7654158518335
# Episode 655: Total Reward = 837.7200885742244
# Episode 656: Total Reward = 1411.9509239408803
# Episode 657: Total Reward = 2579.5161639599005
# Episode 658: Total Reward = 1940.2582490233738
# Episode 659: Total Reward = 1237.8347337604887
# Episode 660: Total Reward = 1983.7654158518335
# Episode 661: Total Reward = 1844.675254451501
# Episode 662: Total Reward = 2139.8575123425094
# Episode 663: Total Reward = 1983.7654158518335
# Episode 664: Total Reward = 1931.9835235246735
# Episode 665: Total Reward = 1973.0004313815698
# Episode 666: Total Reward = 172.256029451014
# Episode 667: Total Reward = 798.9506966699298
# Episode 668: Total Reward = 1927.4522891982042
# Episode 669: Total Reward = 1761.70261239543
# Episode 670: Total Reward = 1528.4214818573735
# Episode 671: Total Reward = 583.5702059054186
# Episode 672: Total Reward = 1928.6716657080397
# Episode 673: Total Reward = 816.7960895147476
# Episode 674: Total Reward = 559.8192382428523
# Episode 675: Total Reward = 1897.703077188541
# Episode 676: Total Reward = 1051.9761777805343
# Episode 677: Total Reward = 1956.3974186126752
# Episode 678: Total Reward = 1218.863778669354
# Episode 679: Total Reward = 1252.8070565356022
# Episode 680: Total Reward = 1983.7654158518335
# Episode 681: Total Reward = 1354.18764033825
# Episode 682: Total Reward = 1983.7654158518335
# Episode 683: Total Reward = 1577.0121915018303
# Episode 684: Total Reward = 1983.7654158518335
# Episode 685: Total Reward = 2711.658901919427
# Episode 686: Total Reward = 639.623432149074
# Episode 687: Total Reward = 1887.4269826297004
# Episode 688: Total Reward = 758.5108762928625
# Episode 689: Total Reward = 1542.0971648950515
# Episode 690: Total Reward = 16.2877915884119
# Episode 691: Total Reward = 1856.8736707695834
# Episode 692: Total Reward = 254.8251226610684
# Episode 693: Total Reward = 1361.2383629126484
# Episode 694: Total Reward = 24.29587682492405
# Episode 695: Total Reward = 1627.224409692278
# Episode 696: Total Reward = 2073.345280901598
# Episode 697: Total Reward = 1877.0208139430717
# Episode 698: Total Reward = 1929.673237009839
# Episode 699: Total Reward = 1970.5800977798212
# Episode 700: Total Reward = 1454.192692272695
# Episode 701: Total Reward = 1983.7654158518335
# Episode 702: Total Reward = 469.48978520332906
# Episode 703: Total Reward = 247.78774714586262
# Episode 704: Total Reward = 1468.4851320731914
# Episode 705: Total Reward = 1904.017348441273
# Episode 706: Total Reward = 1983.7654158518335
# Episode 707: Total Reward = 1966.653946853789
# Episode 708: Total Reward = 1940.1061474749786
# Episode 709: Total Reward = 1983.7654158518335
# Episode 710: Total Reward = 1206.5374389308356
# Episode 711: Total Reward = 1983.7654158518335
# Episode 712: Total Reward = 1983.7654158518335
# Episode 713: Total Reward = 1933.5951662256975
# Episode 714: Total Reward = 1983.7654158518335
# Episode 715: Total Reward = 1340.9651638840867
# Episode 716: Total Reward = 1868.3162072932232
# Episode 717: Total Reward = -26.966034608889125
# Episode 718: Total Reward = 1965.9200230070155
# Episode 719: Total Reward = 1428.9436180996413
# Episode 720: Total Reward = 202.13527503580198
# Episode 721: Total Reward = 1862.5449108478074
# Episode 722: Total Reward = 715.9908375710185
# Episode 723: Total Reward = 874.0718347496256
# Episode 724: Total Reward = 1783.377754515126
# Episode 725: Total Reward = 1738.0504753497837
# Episode 726: Total Reward = 1815.5358127228792
# Episode 727: Total Reward = 1929.673237009839
# Episode 728: Total Reward = 256.0654074649087
# Episode 729: Total Reward = 2918.79213146855
# Episode 730: Total Reward = 1054.387427732108
# Episode 731: Total Reward = 1673.2191725523369
# Episode 732: Total Reward = 1969.6839744622093
# Episode 733: Total Reward = 874.3932656632251
# Episode 734: Total Reward = 1797.8073380178066
# Episode 735: Total Reward = 2121.2604361368235
# Episode 736: Total Reward = 1973.8390417577348
# Episode 737: Total Reward = 62.546200924621935
# Episode 738: Total Reward = 1475.3930480278518
# Episode 739: Total Reward = 1974.0299999999984
# Episode 740: Total Reward = 307.20713337938355
# Episode 741: Total Reward = 1185.7615765286444
# Episode 742: Total Reward = 1983.7654158518335
# Episode 743: Total Reward = 1969.7875025882877
# Episode 744: Total Reward = 1931.9961785344517
# Episode 745: Total Reward = 1983.7654158518335
# Episode 746: Total Reward = 1983.7654158518335
# Episode 747: Total Reward = 1971.2714551938325
# Episode 748: Total Reward = 1931.9961785344517
# Episode 749: Total Reward = 1839.7852959877696
# Episode 750: Total Reward = 95.0100279743776
# Episode 751: Total Reward = 1983.7654158518335
# Episode 752: Total Reward = 310.76216573106313
# Episode 753: Total Reward = 1896.4112205222582
# Episode 754: Total Reward = 1971.7292982859758
# Episode 755: Total Reward = 772.0824443821982
# Episode 756: Total Reward = 179.39124241450187
# Episode 757: Total Reward = 1338.9125842386
# Episode 758: Total Reward = 1970.9355538939362
# Episode 759: Total Reward = 511.8474206113865
# Episode 760: Total Reward = -633.3586704807791
# Episode 761: Total Reward = 118.21659691384528
# Episode 762: Total Reward = 1497.5617936829574
# Episode 763: Total Reward = 1916.277783273897
# Episode 764: Total Reward = 1983.7654158518335
# Episode 765: Total Reward = 1969.7875025882877
# Episode 766: Total Reward = 1844.675254451501
# Episode 767: Total Reward = 1983.7654158518335
# Episode 768: Total Reward = 1388.4155101945933
# Episode 769: Total Reward = 648.2506151863001
# Episode 770: Total Reward = 2217.7607366396
# Episode 771: Total Reward = 821.5427010210207
# Episode 772: Total Reward = 1663.447011915153
# Episode 773: Total Reward = 173.4541061343609
# Episode 774: Total Reward = 948.1295510262516
# Episode 775: Total Reward = 344.5460577085391
# Episode 776: Total Reward = 916.2617617911425
# Episode 777: Total Reward = 1926.2214206833069
# Episode 778: Total Reward = 387.99013618860704
# Episode 779: Total Reward = -597.8716830441659
# Episode 780: Total Reward = -760.6617681593276
# Episode 781: Total Reward = 850.7149660438782
# Episode 782: Total Reward = -191.1561259477843
# Episode 783: Total Reward = 1201.7867678984835
# Episode 784: Total Reward = 1919.5942401932575
# Episode 785: Total Reward = 1983.7654158518335
# Episode 786: Total Reward = 1222.7148264840393
# Episode 787: Total Reward = 1983.7654158518335
# Episode 788: Total Reward = 1983.7654158518335
# Episode 789: Total Reward = 796.7508475646623
# Episode 790: Total Reward = 1916.8667652133886
# Episode 791: Total Reward = 427.8571621949023
# Episode 792: Total Reward = 1983.7654158518335
# Episode 793: Total Reward = 1971.7292982859758
# Episode 794: Total Reward = 1983.7654158518335
# Episode 795: Total Reward = 1844.675254451501
# Episode 796: Total Reward = 1983.7654158518335
# Episode 797: Total Reward = 314.3043094662159
# Episode 798: Total Reward = 1983.7654158518335
# Episode 799: Total Reward = 1967.3901714022763
# Episode 800: Total Reward = 1983.7654158518335
# Episode 801: Total Reward = 1983.7654158518335
# Episode 802: Total Reward = 1844.675254451501
# Episode 803: Total Reward = 1983.7654158518335
# Episode 804: Total Reward = 1946.946132520417
# Episode 805: Total Reward = 1964.585611411479
# Episode 806: Total Reward = 583.5702059054186
# Episode 807: Total Reward = 1983.7654158518335
# Episode 808: Total Reward = 1983.7654158518335
# Episode 809: Total Reward = 1983.7654158518335
# Episode 810: Total Reward = 1983.7654158518335
# Episode 811: Total Reward = 1983.7654158518335
# Episode 812: Total Reward = 1264.2555502964801
# Episode 813: Total Reward = 1983.7654158518335
# Episode 814: Total Reward = 1479.6254277082246
# Episode 815: Total Reward = 700.5116826132542
# Episode 816: Total Reward = 1611.0326096395513
# Episode 817: Total Reward = 1934.4234199930966
# Episode 818: Total Reward = 2918.79213146855
# Episode 819: Total Reward = 1934.3428954331057
# Episode 820: Total Reward = 1782.1825898470265
# Episode 821: Total Reward = 181.08582629539765
# Episode 822: Total Reward = 2791.4921711015977
# Episode 823: Total Reward = 1983.7654158518335
# Episode 824: Total Reward = 1932.2032416887137
# Episode 825: Total Reward = 1916.4468894512815
# Episode 826: Total Reward = 1912.3895916254442
# Episode 827: Total Reward = 1538.1982913029215
# Episode 828: Total Reward = 1877.5788335442294
# Episode 829: Total Reward = 1983.7654158518335
# Episode 830: Total Reward = 1983.7654158518335
# Episode 831: Total Reward = 1973.4088093868613
# Episode 832: Total Reward = 102.31872639593875
# Episode 833: Total Reward = 1983.7654158518335
# Episode 834: Total Reward = 1934.3428954331057
# Episode 835: Total Reward = 1983.7654158518335
# Episode 836: Total Reward = 1965.9200230070155
# Episode 837: Total Reward = 1983.7654158518335
# Episode 838: Total Reward = 1957.6432497411697
# Episode 839: Total Reward = 1983.7654158518335
# Episode 840: Total Reward = 1944.3279408719645
# Episode 841: Total Reward = 1983.7654158518335
# Episode 842: Total Reward = 1553.948918875664
# Episode 843: Total Reward = 1983.7654158518335
# Episode 844: Total Reward = 1614.8816564070191
# Episode 845: Total Reward = 1983.7654158518335
# Episode 846: Total Reward = 1909.8001529966627
# Episode 847: Total Reward = 1389.6746263629648
# Episode 848: Total Reward = 1931.7315943862864
# Episode 849: Total Reward = 1983.7654158518335
# Episode 850: Total Reward = 1930.4547037846528
# Episode 851: Total Reward = 1294.0597109758376
# Episode 852: Total Reward = 1983.7654158518335
# Episode 853: Total Reward = 1973.0004313815698
# Episode 854: Total Reward = 1547.291649333981
# Episode 855: Total Reward = 1983.7654158518335
# Episode 856: Total Reward = 1614.8816564070191
# Episode 857: Total Reward = 1983.7654158518335
# Episode 858: Total Reward = 1357.6774485522612
# Episode 859: Total Reward = 661.5233815291491
# Episode 860: Total Reward = 1919.583891636948
# Episode 861: Total Reward = 1983.7654158518335
# Episode 862: Total Reward = 1970.2338387208083
# Episode 863: Total Reward = 1498.961885302942
# Episode 864: Total Reward = 1052.4776533916508
# Episode 865: Total Reward = 1322.2669199711556
# Episode 866: Total Reward = 1983.7654158518335
# Episode 867: Total Reward = 1369.4228481421285
# Episode 868: Total Reward = 327.6304641178159
# Episode 869: Total Reward = 96.24148798109047
# Episode 870: Total Reward = -825.4276127293214
# Episode 871: Total Reward = -21.196852721376526
# Episode 872: Total Reward = -532.8927626128861
# Episode 873: Total Reward = 2647.9256312582734
# Episode 874: Total Reward = 760.3054192453134
# Episode 875: Total Reward = 1944.3279408719645
# Episode 876: Total Reward = 1983.0395490624624
# Episode 877: Total Reward = 1107.785907005055
# Episode 878: Total Reward = 1983.7654158518335
# Episode 879: Total Reward = 1983.7654158518335
# Episode 880: Total Reward = 1923.575610261128
# Episode 881: Total Reward = 1983.7654158518335
# Episode 882: Total Reward = 1973.0004313815698
# Episode 883: Total Reward = 1515.2711552751257
# Episode 884: Total Reward = 1983.7654158518335
# Episode 885: Total Reward = 1028.4949895848215
# Episode 886: Total Reward = 1983.7654158518335
# Episode 887: Total Reward = 1923.817174738294
# Episode 888: Total Reward = 1983.7654158518335
# Episode 889: Total Reward = 1983.7654158518335
# Episode 890: Total Reward = 2791.4921711015977
# Episode 891: Total Reward = 1983.7654158518335
# Episode 892: Total Reward = 1983.7654158518335
# Episode 893: Total Reward = 1983.7654158518335
# Episode 894: Total Reward = 261.5966210495978
# Episode 895: Total Reward = 1933.5951662256975
# Episode 896: Total Reward = 2261.589356698704
# Episode 897: Total Reward = 1934.1703416542032
# Episode 898: Total Reward = 1872.312513516621
# Episode 899: Total Reward = 1983.7654158518335
# Episode 900: Total Reward = 1983.7654158518335
# Episode 901: Total Reward = 1488.3465032540298
# Episode 902: Total Reward = 1983.7654158518335
# Episode 903: Total Reward = 1962.549494995972
# Episode 904: Total Reward = 1118.4636044808415
# Episode 905: Total Reward = 1673.2191725523369
# Episode 906: Total Reward = 1983.7654158518335
# Episode 907: Total Reward = 1983.7654158518335
# Episode 908: Total Reward = 1516.2458267673055
# Episode 909: Total Reward = 1938.332306453467
# Episode 910: Total Reward = 1892.183676521338
# Episode 911: Total Reward = 1983.7654158518335
# Episode 912: Total Reward = 2082.607119027231
# Episode 913: Total Reward = 1007.5654514527204
# Episode 914: Total Reward = 1983.7654158518335
# Episode 915: Total Reward = 1983.7654158518335
# Episode 916: Total Reward = 1983.7654158518335
# Episode 917: Total Reward = 1970.6951305648208
# Episode 918: Total Reward = 1222.7148264840393
# Episode 919: Total Reward = 1983.7654158518335
# Episode 920: Total Reward = 1983.7654158518335
# Episode 921: Total Reward = 1965.9200230070155
# Episode 922: Total Reward = 1983.7654158518335
# Episode 923: Total Reward = 1983.7654158518335
# Episode 924: Total Reward = 1983.7654158518335
# Episode 925: Total Reward = 1983.7654158518335
# Episode 926: Total Reward = 1983.7654158518335
# Episode 927: Total Reward = 1983.7654158518335
# Episode 928: Total Reward = 1983.7654158518335
# Episode 929: Total Reward = 1983.7654158518335
# Episode 930: Total Reward = 1983.7654158518335
# Episode 931: Total Reward = 1983.7654158518335
# Episode 932: Total Reward = 1983.7654158518335
# Episode 933: Total Reward = 1983.7654158518335
# Episode 934: Total Reward = 1983.7654158518335
# Episode 935: Total Reward = 1256.820630835467
# Episode 936: Total Reward = 1969.7875025882877
# Episode 937: Total Reward = 1673.2191725523369
# Episode 938: Total Reward = 1983.7654158518335
# Episode 939: Total Reward = 1983.7654158518335
# Episode 940: Total Reward = 1983.7654158518335
# Episode 941: Total Reward = 583.5702059054186
# Episode 942: Total Reward = 1983.7654158518335
# Episode 943: Total Reward = 1983.7654158518335
# Episode 944: Total Reward = 1000.1822196233691
# Episode 945: Total Reward = 1983.7654158518335
# Episode 946: Total Reward = 1971.9777694696868
# Episode 947: Total Reward = 2918.79213146855
# Episode 948: Total Reward = 1983.7654158518335
# Episode 949: Total Reward = 1973.0004313815698
# Episode 950: Total Reward = 1943.718248015643
# Episode 951: Total Reward = 1983.7654158518335
# Episode 952: Total Reward = 1210.8706968652655
# Episode 953: Total Reward = 1983.7654158518335
# Episode 954: Total Reward = 1983.7654158518335
# Episode 955: Total Reward = 1983.7654158518335
# Episode 956: Total Reward = 1983.7654158518335
# Episode 957: Total Reward = 1966.653946853789
# Episode 958: Total Reward = 1970.6951305648208
# Episode 959: Total Reward = 1983.7654158518335
# Episode 960: Total Reward = 1973.8390417577348
# Episode 961: Total Reward = 708.9950881367565
# Episode 962: Total Reward = 1927.5328114574932
# Episode 963: Total Reward = 1983.7654158518335
# Episode 964: Total Reward = 1983.7654158518335
# Episode 965: Total Reward = 578.8882345743522
# Episode 966: Total Reward = 1892.4321569078556
# Episode 967: Total Reward = 1488.7658240031844
# Episode 968: Total Reward = 1915.6140273783487
# Episode 969: Total Reward = 1095.5844145770416
# Episode 970: Total Reward = 1576.187301303686
# Episode 971: Total Reward = 1528.4214818573735
# Episode 972: Total Reward = 1938.5520257678577
# Episode 973: Total Reward = 1965.7003036926249
# Episode 974: Total Reward = 1933.5951662256975
# Episode 975: Total Reward = 1972.1434257448504
# Episode 976: Total Reward = 1983.7654158518335
# Episode 977: Total Reward = 1983.7654158518335
# Episode 978: Total Reward = 1983.7654158518335
# Episode 979: Total Reward = 1968.97075347981
# Episode 980: Total Reward = 1983.7654158518335
# Episode 981: Total Reward = 1983.7654158518335
# Episode 982: Total Reward = 1983.7654158518335
# Episode 983: Total Reward = 1983.7654158518335
# Episode 984: Total Reward = 1983.7654158518335
# Episode 985: Total Reward = 1983.7654158518335
# Episode 986: Total Reward = 800.1543816732587
# Episode 987: Total Reward = 1528.4214818573735
# Episode 988: Total Reward = 1983.7654158518335
# Episode 989: Total Reward = 1983.7654158518335
# Episode 990: Total Reward = 1680.9126444974029
# Episode 991: Total Reward = 370.318447473549
# Episode 992: Total Reward = 1801.8708040952479
# Episode 993: Total Reward = 1983.7654158518335
# Episode 994: Total Reward = 1983.7654158518335
# Episode 995: Total Reward = 1983.7654158518335
# Episode 996: Total Reward = 1983.7654158518335
# Episode 997: Total Reward = 1970.2338387208083
# Episode 998: Total Reward = 1983.7654158518335
# Episode 999: Total Reward = 1983.7654158518335
# Episode 1000: Total Reward = 1983.7654158518335

# %% [markdown]
# ## Conclusion
#
# As we can see, after evaulating the trained model, the profit of the agent has increased significantly after 100 days. There is almost 30% increase in profit for the agent.
